# %% [markdown]
# ## Import Dependencies

# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Define Env Function

# %%
def make_bipedal_env(stage):
    import gymnasium as gym

    hardcore = stage.get("hardcore", False)

    return gym.make("BipedalWalker-v3",
                    hardcore=hardcore)

bipedal_stages = [
    {
        "name": "easy",
        "hardcore": False,
        "parcial_timesteps": 250_000,
    },
    {
        "name": "hardcore",
        "hardcore": True,
        "parcial_timesteps": 250_000,
    },
]

# %%
tmp_path = "./results/ppo-curriculum-bipedalwalker-2"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model = None
    
for i, stage in enumerate(bipedal_stages):
    print(f"🚶‍♂️ Treinando estágio {i+1}: {stage['name']}")
    env = make_bipedal_env(stage)

    if model is None:
        model = PPO("MlpPolicy", env, verbose=1)
        model.set_logger(new_logger)
    else:
        model.set_env(env)

    model.learn(stage.get("parcial_timesteps", 100_000),
                reset_num_timesteps=False)
    print(f"🏆 Avaliando o modelo no estágio {i+1}: {stage['name']}")
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
    print(f"🏆 Avaliação média: {mean_reward:.2f} +/- {std_reward:.2f}")
    model.save(f"./saved_models/ppo_bipedal_stage_{i+1}")
# Out:
# Logging to ./results/ppo-curriculum-bipedalwalker-2
# 🚶‍♂️ Treinando estágio 1: easy
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 387      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    fps             | 328      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 520          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0061618695 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | -0.014       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.3         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00685     |
# |    std                  | 1            |
# |    value_loss           | 153          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 535          |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 228          |
# |    iterations           | 3            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0121005345 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.0304       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.541        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.009       |
# |    std                  | 0.999        |
# |    value_loss           | 38.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 585         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 4           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010937041 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0085     |
# |    std                  | 0.993       |
# |    value_loss           | 61.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 730        |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 196        |
# |    iterations           | 5          |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01047794 |
# |    clip_fraction        | 0.0844     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.64      |
# |    explained_variance   | -0.0741    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 142        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00392   |
# |    std                  | 0.987      |
# |    value_loss           | 31         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 788         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 6           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008876182 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00722    |
# |    std                  | 0.983       |
# |    value_loss           | 0.499       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 7           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009723808 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | -0.997      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0953      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.963       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 697         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 8           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004389653 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 0.962       |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 736         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 9           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010400057 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.226       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.967       |
# |    value_loss           | 0.559       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 805         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 10          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007920133 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.0765      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.033       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00897    |
# |    std                  | 0.955       |
# |    value_loss           | 0.158       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 11          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008626904 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.0581      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.934       |
# |    value_loss           | 0.176       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 864          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 169          |
# |    iterations           | 12           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0112294275 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.36        |
# |    explained_variance   | -0.00102     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0445       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 0.918        |
# |    value_loss           | 0.0825       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | -103         |
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 13           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0096245725 |
# |    clip_fraction        | 0.0914       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.28        |
# |    explained_variance   | -0.116       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0111       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.899        |
# |    value_loss           | 0.0941       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 839         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 14          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004678515 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.0145      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00225    |
# |    std                  | 0.902       |
# |    value_loss           | 23.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 861         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 15          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004406389 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.26       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00507    |
# |    std                  | 0.902       |
# |    value_loss           | 66.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 881          |
# |    ep_rew_mean          | -103         |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 16           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0090559535 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.23        |
# |    explained_variance   | 0.399        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00409      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 0.891        |
# |    value_loss           | 0.176        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 901         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 17          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010301057 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00969    |
# |    std                  | 0.886       |
# |    value_loss           | 0.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 18          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007825175 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.16       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.878       |
# |    value_loss           | 0.0762      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 953         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 19          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009783495 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.13       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0505      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.869       |
# |    value_loss           | 0.171       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 20          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009209136 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0378      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.857       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 998         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 21          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007657856 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.061       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.852       |
# |    value_loss           | 0.0762      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -99.8       |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 22          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010740522 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.0595      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0292      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00985    |
# |    std                  | 0.841       |
# |    value_loss           | 0.0871      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -99.2       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 23          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006826631 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.537       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 0.838       |
# |    value_loss           | 18.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -98.7       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 24          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008711532 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | -1.92       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00732    |
# |    std                  | 0.825       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -97.8       |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 25          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009629729 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.88       |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00431     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00928    |
# |    std                  | 0.815       |
# |    value_loss           | 0.0627      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | -97.2       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 26          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010377026 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -4.04e-05   |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.801       |
# |    value_loss           | 0.0771      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -96.7       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 27          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010476093 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00988     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.789       |
# |    value_loss           | 0.0557      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | -96.2       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 28          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009403004 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.773       |
# |    value_loss           | 0.0625      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -94.9       |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 29          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010067873 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.018       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00945    |
# |    std                  | 0.766       |
# |    value_loss           | 0.061       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | -94.3       |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 30          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008420595 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0323      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.76        |
# |    value_loss           | 0.129       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | -93.7       |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 31          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009324347 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0406      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00793    |
# |    std                  | 0.749       |
# |    value_loss           | 0.0674      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | -92.2       |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 32          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012127442 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.011       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.747       |
# |    value_loss           | 0.0719      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -91.4       |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 33          |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008423651 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0529      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.008      |
# |    std                  | 0.742       |
# |    value_loss           | 0.0952      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -90.6       |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 34          |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010969932 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0329      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.736       |
# |    value_loss           | 0.0949      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | -89.7        |
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 35           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0094452575 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.43        |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0493       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.733        |
# |    value_loss           | 0.138        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -87.8       |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 36          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011537498 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0646      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.729       |
# |    value_loss           | 0.136       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.17e+03     |
# |    ep_rew_mean          | -86.9        |
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 37           |
# |    time_elapsed         | 542          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0074374983 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.38        |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.038        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 0.718        |
# |    value_loss           | 0.132        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.18e+03   |
# |    ep_rew_mean          | -85.9      |
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 38         |
# |    time_elapsed         | 557        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01167542 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.31      |
# |    explained_variance   | 0.832      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0728     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0142    |
# |    std                  | 0.705      |
# |    value_loss           | 0.125      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -83.9       |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 39          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011335609 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0619      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.697       |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -82.8       |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 40          |
# |    time_elapsed         | 597         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009515168 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0814      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.69        |
# |    value_loss           | 0.227       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -81.5       |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 41          |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011252785 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0763      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.69        |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | -80.3       |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 42          |
# |    time_elapsed         | 629         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011578818 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0949      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.684       |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | -77.8       |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 43          |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011401327 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0805      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.68        |
# |    value_loss           | 0.184       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | -76.4       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 44          |
# |    time_elapsed         | 663         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009273247 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0326      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00932    |
# |    std                  | 0.668       |
# |    value_loss           | 0.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | -75.6       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 45          |
# |    time_elapsed         | 678         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009215967 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0894      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.661       |
# |    value_loss           | 0.207       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | -74.2       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 46          |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008673685 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.117       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00697    |
# |    std                  | 0.659       |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | -71.4       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 47          |
# |    time_elapsed         | 712         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014522788 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0911      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.648       |
# |    value_loss           | 0.233       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | -69.8       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 48          |
# |    time_elapsed         | 725         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012583578 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.636       |
# |    value_loss           | 0.266       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | -68.2       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 49          |
# |    time_elapsed         | 741         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011944255 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0962      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.627       |
# |    value_loss           | 0.301       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.25e+03    |
# |    ep_rew_mean          | -65.4       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 50          |
# |    time_elapsed         | 752         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010543752 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0459      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.624       |
# |    value_loss           | 0.169       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.25e+03    |
# |    ep_rew_mean          | -63.9       |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 51          |
# |    time_elapsed         | 763         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.012360053 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0488      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.62        |
# |    value_loss           | 0.234       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -62.3       |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 52          |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013256079 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0763      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00764    |
# |    std                  | 0.613       |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -60.6       |
# | time/                   |             |
# ...
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.81        |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.369       |
# |    value_loss           | 44.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 909         |
# |    ep_rew_mean          | -74.9       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 107         |
# |    time_elapsed         | 1073        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.028367985 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74        |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 0.368       |
# |    value_loss           | 6.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | -75.4       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 108         |
# |    time_elapsed         | 1079        |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.019505188 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.369       |
# |    value_loss           | 29.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | -74.2       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 109         |
# |    time_elapsed         | 1085        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.013952604 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.61        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.37        |
# |    value_loss           | 37.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 871         |
# |    ep_rew_mean          | -73.8       |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 110         |
# |    time_elapsed         | 1091        |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.027313676 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.852       |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00747    |
# |    std                  | 0.371       |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 884         |
# |    ep_rew_mean          | -73.7       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 111         |
# |    time_elapsed         | 1097        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.018561982 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33        |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00836    |
# |    std                  | 0.375       |
# |    value_loss           | 8.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 898         |
# |    ep_rew_mean          | -73.8       |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 112         |
# |    time_elapsed         | 1104        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.026330726 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -0.487      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.193       |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00783    |
# |    std                  | 0.37        |
# |    value_loss           | 0.659       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 910        |
# |    ep_rew_mean          | -73.3      |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 113        |
# |    time_elapsed         | 1110       |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.01588859 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.69       |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | -0.00975   |
# |    std                  | 0.371      |
# |    value_loss           | 6.91       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -73         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 114         |
# |    time_elapsed         | 1116        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.015686374 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00979    |
# |    std                  | 0.371       |
# |    value_loss           | 10          |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 889       |
# |    ep_rew_mean          | -73.9     |
# | time/                   |           |
# |    fps                  | 209       |
# |    iterations           | 115       |
# |    time_elapsed         | 1121      |
# |    total_timesteps      | 487424    |
# | train/                  |           |
# |    approx_kl            | 0.0083663 |
# |    clip_fraction        | 0.0827    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.68     |
# |    explained_variance   | 0.883     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 10.2      |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | -0.00874  |
# |    std                  | 0.37      |
# |    value_loss           | 33.6      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 882         |
# |    ep_rew_mean          | -73.3       |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 116         |
# |    time_elapsed         | 1127        |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.013704742 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.25        |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.367       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 894         |
# |    ep_rew_mean          | -74.1       |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 117         |
# |    time_elapsed         | 1133        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.012992542 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00939    |
# |    std                  | 0.368       |
# |    value_loss           | 24.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 909         |
# |    ep_rew_mean          | -73.9       |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 118         |
# |    time_elapsed         | 1139        |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.012448313 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64        |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00917    |
# |    std                  | 0.368       |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 909         |
# |    ep_rew_mean          | -74.3       |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 119         |
# |    time_elapsed         | 1144        |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.013010556 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.41        |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.00523    |
# |    std                  | 0.367       |
# |    value_loss           | 7.08        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 919        |
# |    ep_rew_mean          | -74.9      |
# | time/                   |            |
# |    fps                  | 213        |
# |    iterations           | 120        |
# |    time_elapsed         | 1150       |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.02965223 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | -0.562     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.647      |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.0062    |
# |    std                  | 0.362      |
# |    value_loss           | 1.93       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 921         |
# |    ep_rew_mean          | -75         |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 121         |
# |    time_elapsed         | 1156        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.016854355 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.54        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00758    |
# |    std                  | 0.36        |
# |    value_loss           | 17.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 923        |
# |    ep_rew_mean          | -74.9      |
# | time/                   |            |
# |    fps                  | 215        |
# |    iterations           | 122        |
# |    time_elapsed         | 1161       |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.02903724 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.6       |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.00787   |
# |    std                  | 0.363      |
# |    value_loss           | 4.35       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 927         |
# |    ep_rew_mean          | -75.1       |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 123         |
# |    time_elapsed         | 1167        |
# |    total_timesteps      | 503808      |
# | train/                  |             |
# |    approx_kl            | 0.026782978 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | -0.277      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.498       |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.364       |
# |    value_loss           | 2.73        |
# -----------------------------------------
# 🏆 Avaliando o modelo no estágio 2: hardcore
# 🏆 Avaliação média: -64.28 +/- 39.06

# %%
model.save("./saved_models/ppo-curriculum-bipedalwalker-2")

# %% [markdown]
# ## Inference

# %%
env_eval = gym.make("BipedalWalker-v3",
                    hardcore=False,
                    render_mode="human")
mean_reward, std_reward = evaluate_policy(model, 
                                          env_eval, 
                                          n_eval_episodes=1,
                                          render=True)
env_eval.close()

# %%
env_eval = gym.make("BipedalWalker-v3",
                    hardcore=True,
                    render_mode="human")
mean_reward, std_reward = evaluate_policy(model, 
                                          env_eval, 
                                          n_eval_episodes=1,
                                          render=True)
env_eval.close()
# Out:
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
env_eval.close()

# %% [markdown]
# ## Long

# %%
bipedal_stages = [
    {
        "name": "easy",
        "hardcore": False,
        "parcial_timesteps": 1_000_000,
    },
    {
        "name": "hardcore",
        "hardcore": True,
        "parcial_timesteps": 1_000_000,
    },
]

# %%
tmp_path = "./results/ppo-curriculum-bipedalwalker-long"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model = None
    
for i, stage in enumerate(bipedal_stages):
    print(f"🚶‍♂️ Treinando estágio {i+1}: {stage['name']}")
    env = make_bipedal_env(stage)

    if model is None:
        model = PPO("MlpPolicy", env, verbose=1)
        model.set_logger(new_logger)
    else:
        model.set_env(env)

    model.learn(stage.get("parcial_timesteps", 100_000),
                reset_num_timesteps=False)
    print(f"🏆 Avaliando o modelo no estágio {i+1}: {stage['name']}")
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
    print(f"🏆 Avaliação média: {mean_reward:.2f} +/- {std_reward:.2f}")
    model.save(f"./saved_models/ppo_bipedal_long_stage_{i+1}")
# Out:
# Logging to ./results/ppo-curriculum-bipedalwalker-long
# 🚶‍♂️ Treinando estágio 1: easy
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.6e+03  |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    fps             | 197      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 828        |
# |    ep_rew_mean          | -106       |
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 2          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01150492 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.66      |
# |    explained_variance   | -0.194     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.24       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0159    |
# |    std                  | 0.994      |
# |    value_loss           | 0.528      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 836          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 150          |
# |    iterations           | 3            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0038802172 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | -0.000596    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.894        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.992        |
# |    value_loss           | 66.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 4           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006827671 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.989       |
# |    value_loss           | 34.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 5           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013347009 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | -0.0401     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0521      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.975       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 6           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009692904 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0338      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.95        |
# |    value_loss           | 0.174       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.18e+03   |
# |    ep_rew_mean          | -104       |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 7          |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01168569 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.4       |
# |    explained_variance   | 0.405      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0215     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.922      |
# |    value_loss           | 0.0767     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.25e+03   |
# |    ep_rew_mean          | -102       |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 8          |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01191244 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.31      |
# |    explained_variance   | 0.605      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0112     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0131    |
# |    std                  | 0.905      |
# |    value_loss           | 0.0648     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 9           |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010623612 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0378      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.887       |
# |    value_loss           | 0.0661      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.29e+03    |
# |    ep_rew_mean          | -98.8       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 10          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011868166 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.15       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0224      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.871       |
# |    value_loss           | 0.0687      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.31e+03    |
# |    ep_rew_mean          | -96.8       |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 11          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008714907 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0117      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.862       |
# |    value_loss           | 0.0656      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | -95.1       |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 12          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009168045 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.03        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.854       |
# |    value_loss           | 0.0789      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.29e+03    |
# |    ep_rew_mean          | -93.3       |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 13          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007792274 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.0672      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.37        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00802    |
# |    std                  | 0.85        |
# |    value_loss           | 25.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.25e+03   |
# |    ep_rew_mean          | -92.6      |
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 14         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01211332 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.01      |
# |    explained_variance   | 0.656      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0558     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0144    |
# |    std                  | 0.845      |
# |    value_loss           | 0.109      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+03     |
# |    ep_rew_mean          | -91.2        |
# | time/                   |              |
# |    fps                  | 138          |
# |    iterations           | 15           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0070122415 |
# |    clip_fraction        | 0.065        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5           |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.079        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00533     |
# |    std                  | 0.844        |
# |    value_loss           | 22.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.29e+03     |
# |    ep_rew_mean          | -89.4        |
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 16           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0072166133 |
# |    clip_fraction        | 0.0891       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.98        |
# |    explained_variance   | 0.798        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0768       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.836        |
# |    value_loss           | 0.328        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.31e+03    |
# |    ep_rew_mean          | -88.1       |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 17          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010367073 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.822       |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.32e+03    |
# |    ep_rew_mean          | -86.8       |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 18          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010899777 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.806       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -84.8       |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 19          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010043178 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0316      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.793       |
# |    value_loss           | 0.0816      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.35e+03   |
# |    ep_rew_mean          | -83.4      |
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 20         |
# |    time_elapsed         | 296        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00907903 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.72      |
# |    explained_variance   | 0.515      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0193     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.785      |
# |    value_loss           | 0.0832     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.35e+03    |
# |    ep_rew_mean          | -82.2       |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 21          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010651547 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0561      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.775       |
# |    value_loss           | 0.0946      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.36e+03    |
# |    ep_rew_mean          | -81.1       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 22          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012568609 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0341      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.763       |
# |    value_loss           | 0.0864      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -78.6       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 23          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012054862 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.026       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.753       |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -77.2       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 24          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013003008 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0558      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.747       |
# |    value_loss           | 0.176       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.39e+03    |
# |    ep_rew_mean          | -76         |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 25          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009425101 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0573      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.735       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | -72.7       |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 26          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011883007 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0626      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.726       |
# |    value_loss           | 0.157       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.4e+03      |
# |    ep_rew_mean          | -71          |
# | time/                   |              |
# |    fps                  | 132          |
# |    iterations           | 27           |
# |    time_elapsed         | 417          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0101951435 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.37        |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0403       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0128      |
# |    std                  | 0.718        |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.41e+03   |
# |    ep_rew_mean          | -69.2      |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 28         |
# |    time_elapsed         | 434        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01081332 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.33      |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0627     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0148    |
# |    std                  | 0.714      |
# |    value_loss           | 0.138      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -68.5       |
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 29          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011253621 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0505      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.712       |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.39e+03   |
# |    ep_rew_mean          | -64.9      |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 30         |
# |    time_elapsed         | 469        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.01033498 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.31      |
# |    explained_variance   | -0.149     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.3       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00939   |
# |    std                  | 0.712      |
# |    value_loss           | 37.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -63.4       |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 31          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010096395 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0858      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.704       |
# |    value_loss           | 0.356       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -61.1       |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 32          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010641375 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.181       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00469    |
# |    std                  | 0.701       |
# |    value_loss           | 17.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.39e+03   |
# |    ep_rew_mean          | -58.9      |
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 33         |
# |    time_elapsed         | 520        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01110736 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.787      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.111      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.691      |
# |    value_loss           | 0.238      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.39e+03    |
# |    ep_rew_mean          | -56.9       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 34          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.013765045 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0948      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.682       |
# |    value_loss           | 0.226       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | -52.9       |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 35          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010734394 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0758      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.674       |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | -50.8       |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 36          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011813519 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0807      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.667       |
# |    value_loss           | 0.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41e+03    |
# |    ep_rew_mean          | -48.6       |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 37          |
# |    time_elapsed         | 581         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010790167 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0917      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.659       |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41e+03    |
# |    ep_rew_mean          | -44.2       |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 38          |
# |    time_elapsed         | 598         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010877814 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.095       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.654       |
# |    value_loss           | 0.246       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | -42.9       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 39          |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012674592 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0724      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.648       |
# |    value_loss           | 0.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | -40.4       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 40          |
# |    time_elapsed         | 632         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013474258 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.291       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.651       |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | -38.2       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 41          |
# |    time_elapsed         | 649         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010221685 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.194       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00904    |
# |    std                  | 0.64        |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41e+03    |
# |    ep_rew_mean          | -33.9       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 42          |
# |    time_elapsed         | 665         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015543474 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0661      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.63        |
# |    value_loss           | 0.153       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41e+03    |
# |    ep_rew_mean          | -31.9       |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 43          |
# |    time_elapsed         | 683         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013036437 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0919      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.627       |
# |    value_loss           | 0.223       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.39e+03     |
# |    ep_rew_mean          | -31.1        |
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 44           |
# |    time_elapsed         | 698          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0097170705 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.78        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.624        |
# |    value_loss           | 0.307        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -30.3       |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 45          |
# |    time_elapsed         | 715         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007975905 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.624       |
# |    value_loss           | 21          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -26.3       |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 46          |
# |    time_elapsed         | 731         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.010107178 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | -0.00324    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.58        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0079     |
# |    std                  | 0.625       |
# |    value_loss           | 40.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.37e+03    |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 47          |
# |    time_elapsed         | 747         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.009588454 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.332       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00735    |
# |    std                  | 0.615       |
# |    value_loss           | 0.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -23.2       |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 48          |
# |    time_elapsed         | 763         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010164827 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00477    |
# |    std                  | 0.613       |
# |    value_loss           | 11.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -21.4       |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 49          |
# |    time_elapsed         | 779         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011071539 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.71        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.612       |
# |    value_loss           | 1.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -19.5       |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 50          |
# |    time_elapsed         | 794         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.009566588 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00859    |
# |    std                  | 0.6         |
# |    value_loss           | 0.492       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.36e+03   |
# |    ep_rew_mean          | -18.8      |
# | time/                   |            |
# |    fps                  | 128        |
# |    iterations           | 51         |
# |    time_elapsed         | 810        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.01216194 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.146      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.013     |
# |    std                  | 0.585      |
# |    value_loss           | 0.41       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -19.2       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 52          |
# |    time_elapsed         | 825         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009506825 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 510         |
# ...
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24       |
# |    n_updates            | 9600       |
# |    policy_gradient_loss | -0.00626   |
# |    std                  | 0.167      |
# |    value_loss           | 4.77       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | -71.2       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 473         |
# |    time_elapsed         | 7805        |
# |    total_timesteps      | 1970176     |
# | train/                  |             |
# |    approx_kl            | 0.058847517 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.61        |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52        |
# |    n_updates            | 9610        |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.165       |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 606         |
# |    ep_rew_mean          | -71.5       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 474         |
# |    time_elapsed         | 7817        |
# |    total_timesteps      | 1972224     |
# | train/                  |             |
# |    approx_kl            | 0.055333555 |
# |    clip_fraction        | 0.48        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.62        |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.242       |
# |    n_updates            | 9620        |
# |    policy_gradient_loss | 0.0014      |
# |    std                  | 0.166       |
# |    value_loss           | 0.787       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 614         |
# |    ep_rew_mean          | -71.6       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 475         |
# |    time_elapsed         | 7829        |
# |    total_timesteps      | 1974272     |
# | train/                  |             |
# |    approx_kl            | 0.019013543 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.61        |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.05        |
# |    n_updates            | 9630        |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.166       |
# |    value_loss           | 16.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 612        |
# |    ep_rew_mean          | -71.5      |
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 476        |
# |    time_elapsed         | 7841       |
# |    total_timesteps      | 1976320    |
# | train/                  |            |
# |    approx_kl            | 0.06687814 |
# |    clip_fraction        | 0.448      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.6        |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0455     |
# |    n_updates            | 9640       |
# |    policy_gradient_loss | -0.00824   |
# |    std                  | 0.166      |
# |    value_loss           | 0.473      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 612         |
# |    ep_rew_mean          | -71.3       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 477         |
# |    time_elapsed         | 7853        |
# |    total_timesteps      | 1978368     |
# | train/                  |             |
# |    approx_kl            | 0.033023775 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.61        |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 9650        |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.165       |
# |    value_loss           | 6.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 607         |
# |    ep_rew_mean          | -71.4       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 478         |
# |    time_elapsed         | 7865        |
# |    total_timesteps      | 1980416     |
# | train/                  |             |
# |    approx_kl            | 0.040446803 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.59        |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000204    |
# |    n_updates            | 9660        |
# |    policy_gradient_loss | -0.0078     |
# |    std                  | 0.167       |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | -71.5       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 479         |
# |    time_elapsed         | 7877        |
# |    total_timesteps      | 1982464     |
# | train/                  |             |
# |    approx_kl            | 0.022766061 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.58        |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.01        |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.167       |
# |    value_loss           | 14.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 630         |
# |    ep_rew_mean          | -70.4       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 480         |
# |    time_elapsed         | 7887        |
# |    total_timesteps      | 1984512     |
# | train/                  |             |
# |    approx_kl            | 0.025587246 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.58        |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.933       |
# |    n_updates            | 9680        |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.167       |
# |    value_loss           | 11.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 644         |
# |    ep_rew_mean          | -70.2       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 481         |
# |    time_elapsed         | 7896        |
# |    total_timesteps      | 1986560     |
# | train/                  |             |
# |    approx_kl            | 0.049920216 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.57        |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.669       |
# |    n_updates            | 9690        |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.168       |
# |    value_loss           | 1.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 602         |
# |    ep_rew_mean          | -70.8       |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 482         |
# |    time_elapsed         | 7904        |
# |    total_timesteps      | 1988608     |
# | train/                  |             |
# |    approx_kl            | 0.036867477 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.55        |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.627       |
# |    n_updates            | 9700        |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.168       |
# |    value_loss           | 2.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 602         |
# |    ep_rew_mean          | -70.2       |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 483         |
# |    time_elapsed         | 7912        |
# |    total_timesteps      | 1990656     |
# | train/                  |             |
# |    approx_kl            | 0.014557123 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.56        |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 9710        |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.168       |
# |    value_loss           | 23.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 618         |
# |    ep_rew_mean          | -69.4       |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 484         |
# |    time_elapsed         | 7921        |
# |    total_timesteps      | 1992704     |
# | train/                  |             |
# |    approx_kl            | 0.060606465 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.57        |
# |    explained_variance   | -0.928      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.829       |
# |    n_updates            | 9720        |
# |    policy_gradient_loss | -0.00917    |
# |    std                  | 0.167       |
# |    value_loss           | 4.24        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 619        |
# |    ep_rew_mean          | -69.3      |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 485        |
# |    time_elapsed         | 7930       |
# |    total_timesteps      | 1994752    |
# | train/                  |            |
# |    approx_kl            | 0.05786083 |
# |    clip_fraction        | 0.401      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.58       |
# |    explained_variance   | 0.808      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.361      |
# |    n_updates            | 9730       |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.166      |
# |    value_loss           | 4.16       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 611         |
# |    ep_rew_mean          | -69.2       |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 486         |
# |    time_elapsed         | 7938        |
# |    total_timesteps      | 1996800     |
# | train/                  |             |
# |    approx_kl            | 0.048713893 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.58        |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.359       |
# |    n_updates            | 9740        |
# |    policy_gradient_loss | -0.00825    |
# |    std                  | 0.167       |
# |    value_loss           | 5.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 626         |
# |    ep_rew_mean          | -68.8       |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 487         |
# |    time_elapsed         | 7945        |
# |    total_timesteps      | 1998848     |
# | train/                  |             |
# |    approx_kl            | 0.035205342 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.57        |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.76        |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.167       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 641       |
# |    ep_rew_mean          | -68.4     |
# | time/                   |           |
# |    fps                  | 125       |
# |    iterations           | 488       |
# |    time_elapsed         | 7952      |
# |    total_timesteps      | 2000896   |
# | train/                  |           |
# |    approx_kl            | 0.0582114 |
# |    clip_fraction        | 0.491     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.59      |
# |    explained_variance   | -1.87     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.349     |
# |    n_updates            | 9760      |
# |    policy_gradient_loss | -0.0111   |
# |    std                  | 0.166     |
# |    value_loss           | 0.699     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 659         |
# |    ep_rew_mean          | -68.2       |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 489         |
# |    time_elapsed         | 7958        |
# |    total_timesteps      | 2002944     |
# | train/                  |             |
# |    approx_kl            | 0.049364932 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.59        |
# |    explained_variance   | 0.0697      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0538      |
# |    n_updates            | 9770        |
# |    policy_gradient_loss | -0.00911    |
# |    std                  | 0.166       |
# |    value_loss           | 0.205       |
# -----------------------------------------
# 🏆 Avaliando o modelo no estágio 2: hardcore
# 🏆 Avaliação média: -55.18 +/- 24.60

# %%
model.save(f"./saved_models/ppo_curriculum_bipedal_walker_long")
