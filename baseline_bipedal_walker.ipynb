# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

tmp_path = "./results/ppo-baseline-bipedalwalker"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

env = gym.make("BipedalWalker-v3")
model = PPO(policy="MlpPolicy", env=env)

model.set_logger(new_logger)
model.learn(total_timesteps=500_000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Logging to ./results/ppo-baseline-bipedalwalker
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 461      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    fps             | 577      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 417         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008537619 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | -0.000576   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00735    |
# |    std                  | 1           |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 535         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008554783 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 1.01        |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009647636 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.997       |
# |    value_loss           | 0.457       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 593          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 5            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0029099681 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | 0.0783       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.27         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00286     |
# |    std                  | 0.994        |
# |    value_loss           | 88.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 676         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 6           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009133863 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.361       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.989       |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 725         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 7           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014543477 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.94        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.989       |
# |    value_loss           | 27.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 768         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 8           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011214677 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | -0.17       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.971       |
# |    value_loss           | 0.287       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 777         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 9           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010030976 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0517      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.951       |
# |    value_loss           | 0.0989      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 846        |
# |    ep_rew_mean          | -108       |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 10         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00678726 |
# |    clip_fraction        | 0.0465     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.47      |
# |    explained_variance   | -0.0186    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.96       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0052    |
# |    std                  | 0.949      |
# |    value_loss           | 36.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 876        |
# |    ep_rew_mean          | -107       |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 11         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01117301 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.44      |
# |    explained_variance   | -0.464     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.136      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00872   |
# |    std                  | 0.936      |
# |    value_loss           | 0.338      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 872         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 12          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009574233 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.032       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0628      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.921       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 898         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 13          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009853429 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00705    |
# |    std                  | 0.917       |
# |    value_loss           | 25.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 14          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010424498 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0224      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.91        |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 966         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 15          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012030398 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | -0.000831   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0955      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.898       |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 986         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 16          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009365404 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.22       |
# |    explained_variance   | -0.433      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0407      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.887       |
# |    value_loss           | 0.0963      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 17          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011871733 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.17       |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0879      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.878       |
# |    value_loss           | 0.0934      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 18          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007855691 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.13       |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0637      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00873    |
# |    std                  | 0.865       |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 19          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009967423 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0356      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.851       |
# |    value_loss           | 0.078       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | -99.8       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 20          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009347662 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0143      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.846       |
# |    value_loss           | 0.0695      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | -97.9       |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 21          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011418508 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00392     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.835       |
# |    value_loss           | 0.0753      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.11e+03     |
# |    ep_rew_mean          | -97.1        |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 22           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0110113155 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.91        |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0143       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.82         |
# |    value_loss           | 0.101        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | -96.1       |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 23          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011379764 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.815       |
# |    value_loss           | 0.0736      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.14e+03  |
# |    ep_rew_mean          | -94       |
# | time/                   |           |
# |    fps                  | 367       |
# |    iterations           | 24        |
# |    time_elapsed         | 133       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0105185 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.83     |
# |    explained_variance   | 0.422     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0176    |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0122   |
# |    std                  | 0.806     |
# |    value_loss           | 0.121     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | -93.1      |
# | time/                   |            |
# |    fps                  | 366        |
# |    iterations           | 25         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00844265 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.8       |
# |    explained_variance   | 0.791      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0719     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0111    |
# |    std                  | 0.8        |
# |    value_loss           | 0.131      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -92.1       |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 26          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012667625 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0372      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.789       |
# |    value_loss           | 0.117       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -91.1       |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 27          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009236815 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.053       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.78        |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -88.7       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 28          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008781135 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0616      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.769       |
# |    value_loss           | 0.148       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.2e+03    |
# |    ep_rew_mean          | -87.5      |
# | time/                   |            |
# |    fps                  | 365        |
# |    iterations           | 29         |
# |    time_elapsed         | 162        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01007035 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.61      |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0806     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0103    |
# |    std                  | 0.763      |
# |    value_loss           | 0.179      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | -86         |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 30          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010808841 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.761       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | -84.9       |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 31          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011045627 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.753       |
# |    value_loss           | 0.202       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | -81.7       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 32          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009874832 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0752      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.746       |
# |    value_loss           | 0.201       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | -80.2       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 33          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012962759 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0477      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.743       |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | -78.2       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 34          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012631693 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0831      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.737       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.26e+03   |
# |    ep_rew_mean          | -74.6      |
# | time/                   |            |
# |    fps                  | 363        |
# |    iterations           | 35         |
# |    time_elapsed         | 197        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01504775 |
# |    clip_fraction        | 0.157      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.101      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0155    |
# |    std                  | 0.727      |
# |    value_loss           | 0.201      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -72.7       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 36          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011586793 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00912    |
# |    std                  | 0.722       |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | -70.4       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 37          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010735493 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0685      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.707       |
# |    value_loss           | 0.219       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | -68.3       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 38          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009853791 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0825      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.699       |
# |    value_loss           | 0.229       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | -64.2       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 39          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012256978 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.142       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.691       |
# |    value_loss           | 0.292       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.25e+03    |
# |    ep_rew_mean          | -63.2       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 40          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010777187 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.684       |
# |    value_loss           | 0.404       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -61         |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 41          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008732344 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00662    |
# |    std                  | 0.684       |
# |    value_loss           | 36.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.26e+03   |
# |    ep_rew_mean          | -58.8      |
# | time/                   |            |
# |    fps                  | 363        |
# |    iterations           | 42         |
# |    time_elapsed         | 236        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01198991 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.136      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0107    |
# |    std                  | 0.678      |
# |    value_loss           | 0.264      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -55.3       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 43          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011569502 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.667       |
# |    value_loss           | 0.311       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -52.8       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 44          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009314473 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | -0.117      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.5        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00823    |
# |    std                  | 0.667       |
# |    value_loss           | 45.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+03     |
# |    ep_rew_mean          | -50.4        |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 45           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0130001735 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.04        |
# |    explained_variance   | 0.608        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.191        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 0.662        |
# |    value_loss           | 0.612        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | -47.1       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 46          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011935296 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.167       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.651       |
# |    value_loss           | 0.452       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | -44.9       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 47          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008856884 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00819    |
# |    std                  | 0.648       |
# |    value_loss           | 17.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | -42.4       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 48          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013572563 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.638       |
# |    value_loss           | 0.555       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | -42.8       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 49          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.012450234 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.633       |
# |    value_loss           | 0.441       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -44.3       |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 50          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005990559 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.5        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00646    |
# |    std                  | 0.634       |
# |    value_loss           | 120         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+03     |
# |    ep_rew_mean          | -44.1        |
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 51           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0053230375 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.85        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 123          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00597     |
# |    std                  | 0.635        |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -43.8       |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 52          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005659903 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.47        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00817    |
# |    std                  | 0.635       |
# |    value_loss           | 36.9        |
# ...
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.0097     |
# |    std                  | 0.357       |
# |    value_loss           | 1.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.31e+03    |
# |    ep_rew_mean          | 190         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 229         |
# |    time_elapsed         | 2580        |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.011312565 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.006      |
# |    std                  | 0.357       |
# |    value_loss           | 38.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 230         |
# |    time_elapsed         | 2595        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.017102383 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00714    |
# |    std                  | 0.355       |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.25e+03    |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 231         |
# |    time_elapsed         | 2611        |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.010619322 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.43        |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.0096     |
# |    std                  | 0.355       |
# |    value_loss           | 24.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 232         |
# |    time_elapsed         | 2627        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.017142447 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.355       |
# |    value_loss           | 25.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | 176         |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 233         |
# |    time_elapsed         | 2643        |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.019013086 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.6         |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00842    |
# |    std                  | 0.356       |
# |    value_loss           | 7.67        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.24e+03   |
# |    ep_rew_mean          | 176        |
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 234        |
# |    time_elapsed         | 2659       |
# |    total_timesteps      | 479232     |
# | train/                  |            |
# |    approx_kl            | 0.03028107 |
# |    clip_fraction        | 0.315      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.512      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.378      |
# |    n_updates            | 2330       |
# |    policy_gradient_loss | -0.0106    |
# |    std                  | 0.353      |
# |    value_loss           | 2.36       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 235         |
# |    time_elapsed         | 2675        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.031842772 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.52        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00621    |
# |    std                  | 0.352       |
# |    value_loss           | 3.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 236         |
# |    time_elapsed         | 2699        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.027171768 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.534       |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00951    |
# |    std                  | 0.356       |
# |    value_loss           | 2.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 237         |
# |    time_elapsed         | 2716        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.024049304 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.541       |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.357       |
# |    value_loss           | 1.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 238         |
# |    time_elapsed         | 2734        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.021783803 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.501       |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00705    |
# |    std                  | 0.356       |
# |    value_loss           | 3.89        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.23e+03   |
# |    ep_rew_mean          | 177        |
# | time/                   |            |
# |    fps                  | 178        |
# |    iterations           | 239        |
# |    time_elapsed         | 2749       |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.02274955 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.629      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.37       |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.0064    |
# |    std                  | 0.356      |
# |    value_loss           | 2.1        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 240         |
# |    time_elapsed         | 2765        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.021738913 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.841       |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00627    |
# |    std                  | 0.353       |
# |    value_loss           | 1.36        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.21e+03   |
# |    ep_rew_mean          | 174        |
# | time/                   |            |
# |    fps                  | 177        |
# |    iterations           | 241        |
# |    time_elapsed         | 2780       |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.03338158 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.65       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.1        |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | -0.00772   |
# |    std                  | 0.352      |
# |    value_loss           | 1.57       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.21e+03   |
# |    ep_rew_mean          | 172        |
# | time/                   |            |
# |    fps                  | 177        |
# |    iterations           | 242        |
# |    time_elapsed         | 2797       |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.01866022 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.79       |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.00597   |
# |    std                  | 0.353      |
# |    value_loss           | 6.83       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 243         |
# |    time_elapsed         | 2813        |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.016278846 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.84        |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.00818    |
# |    std                  | 0.352       |
# |    value_loss           | 8.27        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.21e+03   |
# |    ep_rew_mean          | 173        |
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 244        |
# |    time_elapsed         | 2828       |
# |    total_timesteps      | 499712     |
# | train/                  |            |
# |    approx_kl            | 0.02332507 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.0336     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77       |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | -0.0063    |
# |    std                  | 0.351      |
# |    value_loss           | 3.5        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.21e+03   |
# |    ep_rew_mean          | 173        |
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 245        |
# |    time_elapsed         | 2843       |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.02942031 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.742      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.28       |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.011     |
# |    std                  | 0.351      |
# |    value_loss           | 1.29       |
# ----------------------------------------
# Mean reward: 253.7677298 +/- 57.01

# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

tmp_path = "./results/ppo-baseline-bipedalwalker-hardcore"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

env = gym.make("BipedalWalker-v3",
               hardcore=True)
model = PPO(policy="MlpPolicy", env=env)

model.set_logger(new_logger)
model.learn(total_timesteps=500_000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Logging to ./results/ppo-baseline-bipedalwalker-hardcore
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69.6     |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    fps             | 630      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 308          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 479          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0062741237 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | -0.0012      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00783     |
# |    std                  | 1            |
# |    value_loss           | 261          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010371554 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | -0.0436     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00709    |
# |    std                  | 1.01        |
# |    value_loss           | 125         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 373        |
# |    ep_rew_mean          | -108       |
# | time/                   |            |
# |    fps                  | 441        |
# |    iterations           | 4          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00780777 |
# |    clip_fraction        | 0.0545     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.69      |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.91       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00552   |
# |    std                  | 0.998      |
# |    value_loss           | 109        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 432        |
# |    ep_rew_mean          | -108       |
# | time/                   |            |
# |    fps                  | 433        |
# |    iterations           | 5          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01137027 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.64      |
# |    explained_variance   | 0.673      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.293      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0112    |
# |    std                  | 0.988      |
# |    value_loss           | 24.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 6           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012292327 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.0977      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0709      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.985       |
# |    value_loss           | 0.622       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 397         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 7           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010069239 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.978       |
# |    value_loss           | 21.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 405          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 8            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0023456113 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.59        |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00333     |
# |    std                  | 0.98         |
# |    value_loss           | 175          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 456        |
# |    ep_rew_mean          | -110       |
# | time/                   |            |
# |    fps                  | 421        |
# |    iterations           | 9          |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00322345 |
# |    clip_fraction        | 0.0128     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.59      |
# |    explained_variance   | 0.329      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.4       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00594   |
# |    std                  | 0.978      |
# |    value_loss           | 69.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 10          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008301631 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00693    |
# |    std                  | 0.979       |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 491         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 11          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013291927 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.364       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.977       |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 506         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 12          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007525937 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.365       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00706    |
# |    std                  | 0.97        |
# |    value_loss           | 12.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 551         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 13          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009421734 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.87        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.959       |
# |    value_loss           | 11.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 573         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 14          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013407137 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.256       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.939       |
# |    value_loss           | 0.683       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 600         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 15          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012369936 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0805      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.928       |
# |    value_loss           | 0.172       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 606         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 16          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006865157 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 0.0208      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.219       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00872    |
# |    std                  | 0.93        |
# |    value_loss           | 31.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 643         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 17          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006843965 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.66        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00715    |
# |    std                  | 0.93        |
# |    value_loss           | 21.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 644         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 18          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009691516 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0537      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00919    |
# |    std                  | 0.928       |
# |    value_loss           | 0.437       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 661         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 19          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008047629 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.641       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00431    |
# |    std                  | 0.929       |
# |    value_loss           | 44.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 693          |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 20           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0065209833 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.36        |
# |    explained_variance   | 0.286        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.101        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00318     |
# |    std                  | 0.921        |
# |    value_loss           | 0.348        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 21          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009082567 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0593      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.902       |
# |    value_loss           | 0.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 22          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009076779 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.22       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0634      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00685    |
# |    std                  | 0.885       |
# |    value_loss           | 0.109       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 734          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 23           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0029740054 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.18        |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0018      |
# |    std                  | 0.884        |
# |    value_loss           | 10.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 747          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 24           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0062791444 |
# |    clip_fraction        | 0.0771       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.16        |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.148        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00433     |
# |    std                  | 0.875        |
# |    value_loss           | 0.315        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 773         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 25          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009657117 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.862       |
# |    value_loss           | 0.138       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 785         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 26          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007473495 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0476      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.855       |
# |    value_loss           | 0.207       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 797         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 27          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013284152 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.833       |
# |    value_loss           | 0.0376      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 811        |
# |    ep_rew_mean          | -108       |
# | time/                   |            |
# |    fps                  | 395        |
# |    iterations           | 28         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00807039 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.9       |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00212    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0103    |
# |    std                  | 0.819      |
# |    value_loss           | 0.0468     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 820          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 29           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0042232377 |
# |    clip_fraction        | 0.0543       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.87        |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.674        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0055      |
# |    std                  | 0.817        |
# |    value_loss           | 8.93         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 30          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006060371 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00517    |
# |    std                  | 0.819       |
# |    value_loss           | 14.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 839          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 31           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0074695135 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.87        |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00569     |
# |    std                  | 0.818        |
# |    value_loss           | 8.33         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 849         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 32          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008888658 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.022       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0098     |
# |    std                  | 0.816       |
# |    value_loss           | 0.0779      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 859         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 33          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011823812 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0188      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00977    |
# |    std                  | 0.794       |
# |    value_loss           | 0.0569      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 868          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 34           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0052574268 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.74        |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.341        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00522     |
# |    std                  | 0.791        |
# |    value_loss           | 4.68         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 873         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 35          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009296579 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0764      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.783       |
# |    value_loss           | 0.186       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 881          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 36           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0056792665 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.69        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.454        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00662     |
# |    std                  | 0.781        |
# |    value_loss           | 4.31         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 871         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 37          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.016364727 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.14        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00524    |
# |    std                  | 0.782       |
# |    value_loss           | 7.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 879         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 38          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006922777 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00581    |
# |    std                  | 0.781       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 881         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 39          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010598409 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | -0.336      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.184       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00637    |
# |    std                  | 0.772       |
# |    value_loss           | 0.62        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 888          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 40           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0073743295 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00715     |
# |    std                  | 0.771        |
# |    value_loss           | 7.02         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 896         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 41          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010990616 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.589       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.769       |
# |    value_loss           | 0.956       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 895         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 42          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010149635 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00269    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.758       |
# |    value_loss           | 0.074       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 902          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 43           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0069615524 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.56        |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.387        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00639     |
# |    std                  | 0.758        |
# |    value_loss           | 7.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 905         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 44          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011390404 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000712   |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00792    |
# |    std                  | 0.75        |
# |    value_loss           | 0.0281      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 920        |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 389        |
# |    iterations           | 45         |
# |    time_elapsed         | 236        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00777647 |
# |    clip_fraction        | 0.0481     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.52      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.773      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00509   |
# |    std                  | 0.749      |
# |    value_loss           | 5.93       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 936         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 46          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009967398 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.32        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00797    |
# |    std                  | 0.748       |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 951         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 47          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.009588203 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0522      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.739       |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 966         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 48          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013384059 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0389      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00857    |
# |    std                  | 0.733       |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 49          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010715444 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0797      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00838    |
# |    std                  | 0.723       |
# |    value_loss           | 0.249       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 50          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008717844 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.49        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00706    |
# |    std                  | 0.722       |
# |    value_loss           | 5.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 51          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009029818 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | -0.118      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.177       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0098     |
# |    std                  | 0.718       |
# |    value_loss           | 0.589       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 52          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008437309 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# ...
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.374       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -68.1       |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 229         |
# |    time_elapsed         | 2637        |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.016546784 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | -0.285      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.369       |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.00537    |
# |    std                  | 0.37        |
# |    value_loss           | 1.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -69.1       |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 230         |
# |    time_elapsed         | 2652        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.010429969 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.84        |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00802    |
# |    std                  | 0.37        |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -67.9       |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 231         |
# |    time_elapsed         | 2667        |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.020110633 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.223       |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00926    |
# |    std                  | 0.367       |
# |    value_loss           | 0.564       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -67.3       |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 232         |
# |    time_elapsed         | 2682        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.014675258 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.0079     |
# |    std                  | 0.367       |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -68         |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 233         |
# |    time_elapsed         | 2697        |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.010327214 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.07        |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00431    |
# |    std                  | 0.367       |
# |    value_loss           | 8.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -66.6       |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 234         |
# |    time_elapsed         | 2713        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.020097855 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | -0.64       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.36        |
# |    value_loss           | 0.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -67.5       |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 235         |
# |    time_elapsed         | 2728        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.011601487 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.0088     |
# |    std                  | 0.361       |
# |    value_loss           | 7.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -67.1       |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 236         |
# |    time_elapsed         | 2743        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.012536895 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.0075     |
# |    std                  | 0.36        |
# |    value_loss           | 9.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -67.7       |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 237         |
# |    time_elapsed         | 2758        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.015328774 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.45        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.0047     |
# |    std                  | 0.36        |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 991        |
# |    ep_rew_mean          | -69.1      |
# | time/                   |            |
# |    fps                  | 175        |
# |    iterations           | 238        |
# |    time_elapsed         | 2773       |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.01568526 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.48       |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.00847   |
# |    std                  | 0.358      |
# |    value_loss           | 5.01       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 993         |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 239         |
# |    time_elapsed         | 2788        |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.011213287 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.357       |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -68.5       |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 240         |
# |    time_elapsed         | 2803        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.019964643 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.379       |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00418    |
# |    std                  | 0.351       |
# |    value_loss           | 0.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -68         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 241         |
# |    time_elapsed         | 2818        |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.016517393 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.434       |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00778    |
# |    std                  | 0.349       |
# |    value_loss           | 2.21        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 980        |
# |    ep_rew_mean          | -68.1      |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 242        |
# |    time_elapsed         | 2833       |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.02547356 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | 0.895      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.657      |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.00653   |
# |    std                  | 0.349      |
# |    value_loss           | 1.65       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 995         |
# |    ep_rew_mean          | -67.5       |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 243         |
# |    time_elapsed         | 2848        |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.007466738 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.5        |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.00834    |
# |    std                  | 0.349       |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -67.2       |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 244         |
# |    time_elapsed         | 2864        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.018262796 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00754    |
# |    std                  | 0.348       |
# |    value_loss           | 0.484       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.03e+03  |
# |    ep_rew_mean          | -66.4     |
# | time/                   |           |
# |    fps                  | 174       |
# |    iterations           | 245       |
# |    time_elapsed         | 2879      |
# |    total_timesteps      | 501760    |
# | train/                  |           |
# |    approx_kl            | 0.0099139 |
# |    clip_fraction        | 0.11      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.44     |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.48      |
# |    n_updates            | 2440      |
# |    policy_gradient_loss | -0.0101   |
# |    std                  | 0.348     |
# |    value_loss           | 7.71      |
# ---------------------------------------
# Mean reward: -60.717659000000005 +/- 32.54

# %%
model.save("./saved_models/ppo-baseline-bipedalwalker-hardcore")

# %% [markdown]
# ## Inference

# %%
env_eval = gym.make("BipedalWalker-v3",
                    hardcore=True,
                    render_mode="human")
mean_reward, std_reward = evaluate_policy(model, 
                                          env_eval, 
                                          n_eval_episodes=1,
                                          render=True)
env_eval.close()
# Out:
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ## Long

# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

tmp_path = "./results/ppo-baseline-bipedalwalker-hardcore-long"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

env = gym.make("BipedalWalker-v3",
               hardcore=True)
model = PPO(policy="MlpPolicy", env=env)

model.set_logger(new_logger)
model.learn(total_timesteps=2_000_000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Logging to ./results/ppo-baseline-bipedalwalker-hardcore-long
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 461      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    fps             | 385      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 512         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008919507 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.00983     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 1           |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008180882 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00819    |
# |    std                  | 1.01        |
# |    value_loss           | 66.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 506         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007184822 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.21        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00755    |
# |    std                  | 0.999       |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 541         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011576493 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00742    |
# |    std                  | 0.998       |
# |    value_loss           | 78          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 597         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 6           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008057673 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0626      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00707    |
# |    std                  | 0.99        |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 551         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 7           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013262443 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | -0.083      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0522      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.959       |
# |    value_loss           | 0.248       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 574         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 8           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004645815 |
# |    clip_fraction        | 0.0121      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.63        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00406    |
# |    std                  | 0.96        |
# |    value_loss           | 83.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 593         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 9           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009988304 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.294       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00837    |
# |    std                  | 0.957       |
# |    value_loss           | 18.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 10          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004461879 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00712    |
# |    std                  | 0.958       |
# |    value_loss           | 50          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 632         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 11          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010053679 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | -0.167      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00908    |
# |    std                  | 0.941       |
# |    value_loss           | 0.271       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 660          |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 12           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0041731438 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.42        |
# |    explained_variance   | 0.352        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0035      |
# |    std                  | 0.938        |
# |    value_loss           | 44.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 711         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 13          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009615017 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | -1.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0345      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.926       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 734         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 14          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011488667 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0633      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.914       |
# |    value_loss           | 0.177       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 739         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 15          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010849113 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0301      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.902       |
# |    value_loss           | 0.0784      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 760         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 16          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005611555 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.904       |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 781        |
# |    ep_rew_mean          | -111       |
# | time/                   |            |
# |    fps                  | 269        |
# |    iterations           | 17         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01094933 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.25      |
# |    explained_variance   | -0.0329    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0684     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0121    |
# |    std                  | 0.897      |
# |    value_loss           | 0.146      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 818         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 18          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004857691 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.309       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00396    |
# |    std                  | 0.894       |
# |    value_loss           | 11.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 802         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 19          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008792733 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0798      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00901    |
# |    std                  | 0.896       |
# |    value_loss           | 0.671       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 818        |
# |    ep_rew_mean          | -113       |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 20         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00409563 |
# |    clip_fraction        | 0.0273     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.23      |
# |    explained_variance   | 0.76       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.492      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00556   |
# |    std                  | 0.894      |
# |    value_loss           | 26.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 833          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 21           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0057727555 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.23        |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.71         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00611     |
# |    std                  | 0.894        |
# |    value_loss           | 15.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 848        |
# |    ep_rew_mean          | -113       |
# | time/                   |            |
# |    fps                  | 248        |
# |    iterations           | 22         |
# |    time_elapsed         | 181        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00938076 |
# |    clip_fraction        | 0.0823     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.2       |
# |    explained_variance   | 0.479      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.146      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00706   |
# |    std                  | 0.884      |
# |    value_loss           | 0.426      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 862         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 23          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009730169 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.16       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0409      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00617    |
# |    std                  | 0.876       |
# |    value_loss           | 0.665       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 861         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 24          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008329667 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.14       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.29        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00994    |
# |    std                  | 0.876       |
# |    value_loss           | 7.26        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 861          |
# |    ep_rew_mean          | -114         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 25           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0035834522 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.15        |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.3         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0048      |
# |    std                  | 0.877        |
# |    value_loss           | 52.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 858         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 26          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008024705 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.15       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0392      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00841    |
# |    std                  | 0.879       |
# |    value_loss           | 4.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 877          |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 222          |
# |    iterations           | 27           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0059450213 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.14        |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.81         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00338     |
# |    std                  | 0.873        |
# |    value_loss           | 11.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 875         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 28          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009135189 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.13       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.07        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00771    |
# |    std                  | 0.871       |
# |    value_loss           | 5.27        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 877        |
# |    ep_rew_mean          | -116       |
# | time/                   |            |
# |    fps                  | 214        |
# |    iterations           | 29         |
# |    time_elapsed         | 277        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01169087 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.12      |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.54       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00874   |
# |    std                  | 0.873      |
# |    value_loss           | 7.61       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 898         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 30          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011074452 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.246       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00719    |
# |    std                  | 0.868       |
# |    value_loss           | 3.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 897         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 31          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011125807 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | -0.642      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.067       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00946    |
# |    std                  | 0.857       |
# |    value_loss           | 0.295       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 897          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 205          |
# |    iterations           | 32           |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0051291287 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.05        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.27         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00623     |
# |    std                  | 0.855        |
# |    value_loss           | 7.96         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 896         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 33          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006570288 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.05       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00726    |
# |    std                  | 0.855       |
# |    value_loss           | 9.4         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 905          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 34           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0058777994 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.05        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.31         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00465     |
# |    std                  | 0.856        |
# |    value_loss           | 5.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 196          |
# |    iterations           | 35           |
# |    time_elapsed         | 365          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0067265527 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.06        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.753        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00471     |
# |    std                  | 0.86         |
# |    value_loss           | 4.25         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 924         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 36          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011544226 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.05       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00884    |
# |    std                  | 0.854       |
# |    value_loss           | 0.356       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 37          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010206355 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.71        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00749    |
# |    std                  | 0.849       |
# |    value_loss           | 5.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 38          |
# |    time_elapsed         | 414         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006238465 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00811    |
# |    std                  | 0.85        |
# |    value_loss           | 8.03        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 933        |
# |    ep_rew_mean          | -116       |
# | time/                   |            |
# |    fps                  | 185        |
# |    iterations           | 39         |
# |    time_elapsed         | 429        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.00816948 |
# |    clip_fraction        | 0.0551     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.03      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.77       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00844   |
# |    std                  | 0.851      |
# |    value_loss           | 8.63       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 40          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012500294 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5          |
# |    explained_variance   | -0.416      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00884    |
# |    std                  | 0.839       |
# |    value_loss           | 0.316       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 931         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 182         |
# |    iterations           | 41          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005657032 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 0.838       |
# |    value_loss           | 4.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 942         |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 42          |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006519614 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00516    |
# |    std                  | 0.837       |
# |    value_loss           | 4.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 949         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 43          |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005545438 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.24        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00629    |
# |    std                  | 0.837       |
# |    value_loss           | 6.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 44          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008301087 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00737    |
# |    std                  | 0.837       |
# |    value_loss           | 1.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 961         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 45          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013071758 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.464       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00902    |
# |    std                  | 0.838       |
# |    value_loss           | 3.54        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 965          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 46           |
# |    time_elapsed         | 544          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0120501965 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.93        |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0743       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00944     |
# |    std                  | 0.827        |
# |    value_loss           | 0.161        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 964         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 47          |
# |    time_elapsed         | 559         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010140596 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00513    |
# |    std                  | 0.83        |
# |    value_loss           | 1.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 48          |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004445701 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.45        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00394    |
# |    std                  | 0.827       |
# |    value_loss           | 8.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 986         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 49          |
# |    time_elapsed         | 589         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011463031 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.91       |
# |    explained_variance   | -0.336      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.316       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00975    |
# |    std                  | 0.823       |
# |    value_loss           | 0.793       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 50          |
# |    time_elapsed         | 608         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013594497 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | -0.072      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.157       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.83        |
# |    value_loss           | 0.337       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 51          |
# |    time_elapsed         | 626         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.013291009 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0677      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.819       |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 52          |
# |    time_elapsed         | 644         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010621054 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0307      |
# ...
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.659      |
# |    n_updates            | 9590       |
# |    policy_gradient_loss | -0.0169    |
# |    std                  | 0.109      |
# |    value_loss           | 1.12       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -53.6       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 961         |
# |    time_elapsed         | 15237       |
# |    total_timesteps      | 1968128     |
# | train/                  |             |
# |    approx_kl            | 0.033391904 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.27        |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0289     |
# |    n_updates            | 9600        |
# |    policy_gradient_loss | -0.00772    |
# |    std                  | 0.109       |
# |    value_loss           | 0.0259      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.34e+03   |
# |    ep_rew_mean          | -52.6      |
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 962        |
# |    time_elapsed         | 15251      |
# |    total_timesteps      | 1970176    |
# | train/                  |            |
# |    approx_kl            | 0.02990892 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.28       |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0207     |
# |    n_updates            | 9610       |
# |    policy_gradient_loss | -0.00308   |
# |    std                  | 0.108      |
# |    value_loss           | 0.171      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.35e+03    |
# |    ep_rew_mean          | -51.8       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 963         |
# |    time_elapsed         | 15265       |
# |    total_timesteps      | 1972224     |
# | train/                  |             |
# |    approx_kl            | 0.042311616 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.29        |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00863    |
# |    n_updates            | 9620        |
# |    policy_gradient_loss | 0.000473    |
# |    std                  | 0.109       |
# |    value_loss           | 0.0452      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.35e+03    |
# |    ep_rew_mean          | -51.8       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 964         |
# |    time_elapsed         | 15279       |
# |    total_timesteps      | 1974272     |
# | train/                  |             |
# |    approx_kl            | 0.068719104 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.3         |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 9630        |
# |    policy_gradient_loss | -0.00114    |
# |    std                  | 0.108       |
# |    value_loss           | 0.0438      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.35e+03    |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 965         |
# |    time_elapsed         | 15294       |
# |    total_timesteps      | 1976320     |
# | train/                  |             |
# |    approx_kl            | 0.030545812 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.33        |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0285     |
# |    n_updates            | 9640        |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 0.107       |
# |    value_loss           | 0.00935     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 966         |
# |    time_elapsed         | 15308       |
# |    total_timesteps      | 1978368     |
# | train/                  |             |
# |    approx_kl            | 0.047694888 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.33        |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 9650        |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.107       |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.35e+03    |
# |    ep_rew_mean          | -51.3       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 967         |
# |    time_elapsed         | 15323       |
# |    total_timesteps      | 1980416     |
# | train/                  |             |
# |    approx_kl            | 0.039747246 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.33        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.547       |
# |    n_updates            | 9660        |
# |    policy_gradient_loss | 0.00133     |
# |    std                  | 0.107       |
# |    value_loss           | 3.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.35e+03    |
# |    ep_rew_mean          | -51.3       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 968         |
# |    time_elapsed         | 15338       |
# |    total_timesteps      | 1982464     |
# | train/                  |             |
# |    approx_kl            | 0.059065297 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.32        |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0156     |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | -0.00628    |
# |    std                  | 0.107       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.37e+03    |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 969         |
# |    time_elapsed         | 15353       |
# |    total_timesteps      | 1984512     |
# | train/                  |             |
# |    approx_kl            | 0.033219256 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.34        |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0375      |
# |    n_updates            | 9680        |
# |    policy_gradient_loss | 0.00266     |
# |    std                  | 0.107       |
# |    value_loss           | 0.126       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -49.2       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 970         |
# |    time_elapsed         | 15368       |
# |    total_timesteps      | 1986560     |
# | train/                  |             |
# |    approx_kl            | 0.026824422 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.35        |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 9690        |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.106       |
# |    value_loss           | 0.172       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.39e+03   |
# |    ep_rew_mean          | -48.3      |
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 971        |
# |    time_elapsed         | 15383      |
# |    total_timesteps      | 1988608    |
# | train/                  |            |
# |    approx_kl            | 0.03318757 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.38       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0524     |
# |    n_updates            | 9700       |
# |    policy_gradient_loss | -0.0037    |
# |    std                  | 0.105      |
# |    value_loss           | 0.021      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.39e+03   |
# |    ep_rew_mean          | -48.4      |
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 972        |
# |    time_elapsed         | 15398      |
# |    total_timesteps      | 1990656    |
# | train/                  |            |
# |    approx_kl            | 0.04598412 |
# |    clip_fraction        | 0.392      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.41       |
# |    explained_variance   | 0.81       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0678     |
# |    n_updates            | 9710       |
# |    policy_gradient_loss | -0.00245   |
# |    std                  | 0.105      |
# |    value_loss           | 0.251      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.4e+03     |
# |    ep_rew_mean          | -47.6       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 973         |
# |    time_elapsed         | 15413       |
# |    total_timesteps      | 1992704     |
# | train/                  |             |
# |    approx_kl            | 0.032699697 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.44        |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0343      |
# |    n_updates            | 9720        |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.104       |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41e+03    |
# |    ep_rew_mean          | -46.8       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 974         |
# |    time_elapsed         | 15428       |
# |    total_timesteps      | 1994752     |
# | train/                  |             |
# |    approx_kl            | 0.030675065 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.47        |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0224      |
# |    n_updates            | 9730        |
# |    policy_gradient_loss | -0.00174    |
# |    std                  | 0.103       |
# |    value_loss           | 0.015       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.43e+03   |
# |    ep_rew_mean          | -46.2      |
# | time/                   |            |
# |    fps                  | 129        |
# |    iterations           | 975        |
# |    time_elapsed         | 15443      |
# |    total_timesteps      | 1996800    |
# | train/                  |            |
# |    approx_kl            | 0.04851336 |
# |    clip_fraction        | 0.373      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.49       |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0262    |
# |    n_updates            | 9740       |
# |    policy_gradient_loss | -0.00711   |
# |    std                  | 0.103      |
# |    value_loss           | 0.0104     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.43e+03    |
# |    ep_rew_mean          | -46.1       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 976         |
# |    time_elapsed         | 15458       |
# |    total_timesteps      | 1998848     |
# | train/                  |             |
# |    approx_kl            | 0.050848097 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.52        |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0169      |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | -0.0064     |
# |    std                  | 0.101       |
# |    value_loss           | 0.00494     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.43e+03    |
# |    ep_rew_mean          | -46.1       |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 977         |
# |    time_elapsed         | 15473       |
# |    total_timesteps      | 2000896     |
# | train/                  |             |
# |    approx_kl            | 0.032740988 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.58        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0333     |
# |    n_updates            | 9760        |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.0998      |
# |    value_loss           | 0.0046      |
# -----------------------------------------
# Mean reward: -26.0047784 +/- 5.38

# %%
model.save("./saved_models/ppo-baseline-bipedalwalker-hardcore-long")
