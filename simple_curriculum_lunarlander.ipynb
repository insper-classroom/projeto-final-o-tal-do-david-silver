# %% [markdown]
# ## Import Dependencies

# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Define Env Function

# %%
def make_lunar_env(params):
    return gym.make(
        "LunarLander-v3",
        continuous=False,
        gravity=params.get("gravity", -10.0),
        enable_wind=params.get("enable_wind", False),
        wind_power=params.get("wind_power", 0.0),
        turbulence_power=params.get("turbulence_power", 0.0),
        render_mode=None 
    )

curriculum_stages = [
    {
        "name": "easy",
        "gravity": -5.0,
        "enable_wind": False,
        "wind_power": 0.0,
        "turbulence_power": 0.0,
        "parcial_timesteps": 100_000,
    },
    {
        "name": "intermediate",
        "gravity": -10.0,
        "enable_wind": False,
        "wind_power": 0.0,
        "turbulence_power": 0.0,
        "parcial_timesteps": 100_000,
    },
    {
        "name": "hard_with_wind",
        "gravity": -10.0,
        "enable_wind": True,
        "wind_power": 5.0,
        "turbulence_power": 0.5,
        "parcial_timesteps": 100_000,
    },
    {
        "name": "full_difficulty",
        "gravity": -10.0,
        "enable_wind": True,
        "wind_power": 15.0,
        "turbulence_power": 1.5,
        "parcial_timesteps": 100_000,
    }
]

# %%
tmp_path = "./results/ppo-curriculum-lunarlander-1"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model = None

for i, stage in enumerate(curriculum_stages):
    print(f"🔁 Treinando no estágio {i+1}: {stage['name']}")
    env = make_lunar_env(stage)

    if model is None:
        model = PPO("MlpPolicy", env, verbose=1)
        model.set_logger(new_logger)
    else:
        model.set_env(env)

    model.learn(total_timesteps=stage.get("parcial_timesteps", 100_000),
                reset_num_timesteps=False)
    print(f"🏆 Avaliando o modelo no estágio {i+1}: {stage['name']}")
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
    print(f"🏆 Avaliação média: {mean_reward:.2f} +/- {std_reward:.2f}")
    model.save(f"./saved_models/ppo_lunar_stage_{i+1}")
# Out:
# Logging to ./results/ppo-curriculum-lunarlander-1
# 🔁 Treinando no estágio 1: easy
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | -268     |
# | time/              |          |
# |    fps             | 409      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | -256         |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0085056145 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00449      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 510          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 1.38e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | -244        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011471145 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0309     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 491         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00911    |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | -226        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 4           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008440039 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0097     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 242         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 754         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | -213         |
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 5            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0069572516 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00434     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 310          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00869     |
# |    value_loss           | 590          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -209        |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 6           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010603303 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.019       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 372         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | -195        |
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 7           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007837178 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0658      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00662    |
# |    value_loss           | 755         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 178       |
# |    ep_rew_mean          | -185      |
# | time/                   |           |
# |    fps                  | 196       |
# |    iterations           | 8         |
# |    time_elapsed         | 83        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0061547 |
# |    clip_fraction        | 0.0275    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.34     |
# |    explained_variance   | 0.0141    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 185       |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.00694  |
# |    value_loss           | 461       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 185        |
# |    ep_rew_mean          | -182       |
# | time/                   |            |
# |    fps                  | 198        |
# |    iterations           | 9          |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01667217 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -0.0934    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 220        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0144    |
# |    value_loss           | 350        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 10          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006447515 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0018      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 215         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 354         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 204         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 11          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008081085 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0136     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 98.2        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 279         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 216          |
# |    ep_rew_mean          | -150         |
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 12           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0048802933 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0071       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00502     |
# |    value_loss           | 203          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 13          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008887468 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00274     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00886    |
# |    value_loss           | 186         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | -129        |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 14          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008156473 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0181      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.3        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 206         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -126         |
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 15           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0031273752 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.9         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 167          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 277         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 16          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005313959 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.6        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 177         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 295         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 17          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005382497 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 129         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 309         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 18          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010993598 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.9        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0092     |
# |    value_loss           | 72.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 326         |
# |    ep_rew_mean          | -99.2       |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 19          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012107613 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 120         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | -99.6       |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 20          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009614514 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00968    |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 351         |
# |    ep_rew_mean          | -93.5       |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 21          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007305817 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.9        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 371         |
# |    ep_rew_mean          | -84.4       |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 22          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009364672 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.73        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 29.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | -80.7        |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 23           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0074899206 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.4         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00767     |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -77.1       |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 24          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009168307 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00889    |
# |    value_loss           | 82.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | -75          |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 25           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0077044563 |
# |    clip_fraction        | 0.0537       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00894     |
# |    value_loss           | 142          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 433         |
# |    ep_rew_mean          | -66.3       |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 26          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010274807 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 26.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 442         |
# |    ep_rew_mean          | -62.1       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 27          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010278029 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.17        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 458         |
# |    ep_rew_mean          | -53.6       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 28          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010407062 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00846    |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 480          |
# |    ep_rew_mean          | -48.2        |
# | time/                   |              |
# |    fps                  | 215          |
# |    iterations           | 29           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0150899915 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.63         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 11.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 493          |
# |    ep_rew_mean          | -43          |
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 30           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0059383074 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.4         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 35.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 510         |
# |    ep_rew_mean          | -42.2       |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 31          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012854817 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.07        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 5.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | -40.3       |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 32          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008972287 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.74        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00819    |
# |    value_loss           | 13          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 537          |
# |    ep_rew_mean          | -38.8        |
# | time/                   |              |
# |    fps                  | 217          |
# |    iterations           | 33           |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0072446284 |
# |    clip_fraction        | 0.0879       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.96         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00685     |
# |    value_loss           | 40.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 555         |
# |    ep_rew_mean          | -35.7       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 34          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008841552 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.08        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00741    |
# |    value_loss           | 9.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 567         |
# |    ep_rew_mean          | -30.1       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 35          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005219489 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.3        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 50.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 584          |
# |    ep_rew_mean          | -25.4        |
# | time/                   |              |
# |    fps                  | 219          |
# |    iterations           | 36           |
# |    time_elapsed         | 336          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0058794157 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.642        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.91         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 38.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 604         |
# |    ep_rew_mean          | -22.1       |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 37          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012905372 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00917    |
# |    value_loss           | 33.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | -17.4       |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 38          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007919883 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.77        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 71.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 633         |
# |    ep_rew_mean          | -14.8       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 39          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010362634 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.4         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 4.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 640         |
# |    ep_rew_mean          | -10.1       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 40          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009083066 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.02        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 43          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 658         |
# |    ep_rew_mean          | -5.59       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 41          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006902502 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.7        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 43.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 674         |
# |    ep_rew_mean          | 0.178       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 42          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007998515 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.5        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 37.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 688         |
# |    ep_rew_mean          | 4.47        |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 43          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020662017 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 6.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 698         |
# |    ep_rew_mean          | 9.73        |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 44          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010758167 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 91.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 712          |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 45           |
# |    time_elapsed         | 416          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0053517446 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.947       |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00585     |
# |    value_loss           | 80.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 708         |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 46          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009111748 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.8         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 6.57        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 724          |
# |    ep_rew_mean          | 16.8         |
# | time/                   |              |
# |    fps                  | 219          |
# |    iterations           | 47           |
# |    time_elapsed         | 438          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0075991354 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.3         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 98.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 739         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 48          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009510903 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 40.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 728         |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 49          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009849643 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.51        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 8.12        |
# -----------------------------------------
# 🏆 Avaliando o modelo no estágio 1: easy
# 🏆 Avaliação média: 41.89 +/- 102.38
# 🔁 Treinando no estágio 2: intermediate
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 725         |
# |    ep_rew_mean          | 21.4        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 1           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006404626 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.9        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 228         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 727         |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010534944 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.02        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00418    |
# |    value_loss           | 90.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 714         |
# |    ep_rew_mean          | 34.6        |
# | time/                   |             |
# |    fps                  | 310         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011911216 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 121         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 715          |
# |    ep_rew_mean          | 46           |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 4            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0024136063 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.781       |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.4         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 154          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | 51          |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 5           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005797893 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 159         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 699         |
# |    ep_rew_mean          | 60          |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 6           |
# |    time_elapsed         | 39          |
# ...
# |    ep_rew_mean          | 69.2        |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 32          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.006644812 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.6        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 90.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | 74.5         |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 33           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0024781195 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.4         |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.000836    |
# |    value_loss           | 124          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 84.3         |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 34           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 370688       |
# | train/                  |              |
# |    approx_kl            | 0.0037793266 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.608       |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.8         |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 228          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 342          |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 35           |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 372736       |
# | train/                  |              |
# |    approx_kl            | 0.0026233317 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.386       |
# |    explained_variance   | 0.444        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.8         |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 191          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 343        |
# |    ep_rew_mean          | 101        |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 36         |
# |    time_elapsed         | 293        |
# |    total_timesteps      | 374784     |
# | train/                  |            |
# |    approx_kl            | 0.00579662 |
# |    clip_fraction        | 0.0377     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.601     |
# |    explained_variance   | 0.743      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 56.8       |
# |    n_updates            | 1820       |
# |    policy_gradient_loss | -0.00346   |
# |    value_loss           | 153        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 37           |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0026647951 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 230          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 343          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 38           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0055921185 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.9         |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 137          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 39          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.013098821 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72          |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 200         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 40          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.007900899 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 69.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 41          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.005812426 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.4        |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 156         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 42          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.006471986 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.8        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 43          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.005422877 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 144         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 44           |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 391168       |
# | train/                  |              |
# |    approx_kl            | 0.0064069303 |
# |    clip_fraction        | 0.0832       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.3         |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00694     |
# |    value_loss           | 199          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 310          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 45           |
# |    time_elapsed         | 365          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0047179386 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 282          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 46           |
# |    time_elapsed         | 372          |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0020658835 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.611       |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.3         |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 246          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | 124         |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 47          |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.004894078 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.8        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 172         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 308        |
# |    ep_rew_mean          | 125        |
# | time/                   |            |
# |    fps                  | 253        |
# |    iterations           | 48         |
# |    time_elapsed         | 388        |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.00405516 |
# |    clip_fraction        | 0.0333     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.637     |
# |    explained_variance   | 0.72       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 48.7       |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | -0.0027    |
# |    value_loss           | 216        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 301         |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 49          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.004490301 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.7        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 130         |
# -----------------------------------------
# 🏆 Avaliando o modelo no estágio 4: full_difficulty
# 🏆 Avaliação média: 125.30 +/- 129.67

# %% [markdown]
# ## Long

# %%
curriculum_stages = [
    {
        "name": "easy",
        "gravity": -5.0,
        "enable_wind": False,
        "wind_power": 0.0,
        "turbulence_power": 0.0,
        "parcial_timesteps": 500_000,
    },
    {
        "name": "intermediate",
        "gravity": -10.0,
        "enable_wind": False,
        "wind_power": 0.0,
        "turbulence_power": 0.0,
        "parcial_timesteps": 500_000,
    },
    {
        "name": "hard_with_wind",
        "gravity": -10.0,
        "enable_wind": True,
        "wind_power": 5.0,
        "turbulence_power": 0.5,
        "parcial_timesteps": 500_000,
    },
    {
        "name": "full_difficulty",
        "gravity": -10.0,
        "enable_wind": True,
        "wind_power": 15.0,
        "turbulence_power": 1.5,
        "parcial_timesteps": 500_000,
    }
]

# %%
tmp_path = "./results/ppo-curriculum-lunarlander-long"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

model = None

for i, stage in enumerate(curriculum_stages):
    print(f"🔁 Treinando no estágio {i+1}: {stage['name']}")
    env = make_lunar_env(stage)

    if model is None:
        model = PPO("MlpPolicy", env, verbose=1)
        model.set_logger(new_logger)
    else:
        model.set_env(env)

    model.learn(total_timesteps=stage.get("parcial_timesteps", 100_000),
                reset_num_timesteps=False)
    print(f"🏆 Avaliando o modelo no estágio {i+1}: {stage['name']}")
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
    print(f"🏆 Avaliação média: {mean_reward:.2f} +/- {std_reward:.2f}")
    model.save(f"./saved_models/ppo_lunar_long_stage_{i+1}")
# Out:
# Logging to ./results/ppo-curriculum-lunarlander-long
# 🔁 Treinando no estágio 1: easy
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 184      |
# |    ep_rew_mean     | -302     |
# | time/              |          |
# |    fps             | 265      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 174        |
# |    ep_rew_mean          | -298       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 2          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00794119 |
# |    clip_fraction        | 0.0525     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.000792   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 544        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00783   |
# |    value_loss           | 1.1e+03    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | -277         |
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 3            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0024310872 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0763      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 607          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 1.23e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | -256        |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010868202 |
# |    clip_fraction        | 0.084       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0632     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 305         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00831    |
# |    value_loss           | 959         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | -241        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 5           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004934094 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 246         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 809         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | -225        |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 6           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012887686 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00498    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 277         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 690         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | -217         |
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 7            |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0108416155 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00555     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 218          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00968     |
# |    value_loss           | 521          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -208        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 8           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007362874 |
# |    clip_fraction        | 0.0484      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00027    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 244         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 591         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | -204        |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 9           |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005297179 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -6.18e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 419         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 695         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | -186        |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 10          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005483327 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.000532   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 263         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00391    |
# |    value_loss           | 651         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | -169        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 11          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008879734 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 4.11e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 371         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00749    |
# |    value_loss           | 814         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 12          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007921735 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000172   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 137         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 325         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 13          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004797358 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.000129   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 181         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 513         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 219          |
# |    ep_rew_mean          | -145         |
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 14           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0040011574 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -2.47e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 354          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 579          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 15           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0068376153 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -1.6e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 255          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 592          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | -136         |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 16           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0145274615 |
# |    clip_fraction        | 0.185        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.000142    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 184          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 336          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 17          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009225633 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -6.68e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 129         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00686    |
# |    value_loss           | 270         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 267          |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 18           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0048874645 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.000116     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 153          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00559     |
# |    value_loss           | 241          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 284          |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 19           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0062940423 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.0154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.5         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 166          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 296          |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 20           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0066719996 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46           |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00754     |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 21           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0038111922 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.361        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 150          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 188          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | -117         |
# | time/                   |              |
# |    fps                  | 153          |
# |    iterations           | 22           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0044710534 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.41         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00613     |
# |    value_loss           | 191          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 342         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 23          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006418662 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00841    |
# |    value_loss           | 83.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 358         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 24          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008006843 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 371         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 25          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010587916 |
# |    clip_fraction        | 0.0714      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.6        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 71.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 387          |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 150          |
# |    iterations           | 26           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0056014443 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.593        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.7         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 129          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 393        |
# |    ep_rew_mean          | -96.9      |
# | time/                   |            |
# |    fps                  | 149        |
# |    iterations           | 27         |
# |    time_elapsed         | 368        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00485065 |
# |    clip_fraction        | 0.0163     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.725      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 62.9       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00274   |
# |    value_loss           | 110        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 401         |
# |    ep_rew_mean          | -90.6       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 28          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004415169 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 204         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 411         |
# |    ep_rew_mean          | -85.5       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 29          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011283397 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00831    |
# |    value_loss           | 83.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 420          |
# |    ep_rew_mean          | -78.3        |
# | time/                   |              |
# |    fps                  | 145          |
# |    iterations           | 30           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0076972567 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.678        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.5         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 200          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 428          |
# |    ep_rew_mean          | -76.4        |
# | time/                   |              |
# |    fps                  | 145          |
# |    iterations           | 31           |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0036526837 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 142          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 186          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | -63.7       |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 32          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009868394 |
# |    clip_fraction        | 0.0606      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00689    |
# |    value_loss           | 63.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | -59.2        |
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 33           |
# |    time_elapsed         | 469          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0041967696 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.713        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 157          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -57.4       |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 34          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007477661 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 94.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 476         |
# |    ep_rew_mean          | -50.7       |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 35          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007773001 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.46        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 17.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | -47.4       |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 36          |
# |    time_elapsed         | 522         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009574993 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.6        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00863    |
# |    value_loss           | 80.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 508         |
# |    ep_rew_mean          | -43.1       |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 37          |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011354584 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.55        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 14.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 509          |
# |    ep_rew_mean          | -37.7        |
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 38           |
# |    time_elapsed         | 558          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0088743055 |
# |    clip_fraction        | 0.0791       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.806       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.63         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00635     |
# |    value_loss           | 14           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 505          |
# |    ep_rew_mean          | -26.6        |
# | time/                   |              |
# |    fps                  | 138          |
# |    iterations           | 39           |
# |    time_elapsed         | 575          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0057866275 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 108          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 191          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 517         |
# |    ep_rew_mean          | -20         |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 40          |
# |    time_elapsed         | 591         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008557886 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 92          |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 97.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 533         |
# |    ep_rew_mean          | -15.5       |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 41          |
# |    time_elapsed         | 606         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010466899 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.9        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00378    |
# |    value_loss           | 48.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 546         |
# |    ep_rew_mean          | -10.3       |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 42          |
# |    time_elapsed         | 622         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.018114686 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.23        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 10.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | -6.98       |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 43          |
# |    time_elapsed         | 638         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005501746 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 9.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | -0.917      |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 44          |
# |    time_elapsed         | 653         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010397436 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00522    |
# |    value_loss           | 24.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 579         |
# |    ep_rew_mean          | 3.06        |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 45          |
# |    time_elapsed         | 669         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007856717 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.9        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00418    |
# |    value_loss           | 92          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 576         |
# |    ep_rew_mean          | 4.56        |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 46          |
# |    time_elapsed         | 686         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012164082 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.83        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0069     |
# |    value_loss           | 34.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 586          |
# |    ep_rew_mean          | 8.03         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 47           |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0060089007 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.8         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00817     |
# |    value_loss           | 36           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 592          |
# |    ep_rew_mean          | 12.6         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 48           |
# |    time_elapsed         | 721          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0043503502 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 25.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 606         |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 49          |
# |    time_elapsed         | 737         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010283608 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00787    |
# |    value_loss           | 11          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 609         |
# |    ep_rew_mean          | 24.7        |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 50          |
# |    time_elapsed         | 754         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011395044 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.22        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00487    |
# |    value_loss           | 58.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 612         |
# |    ep_rew_mean          | 28.5        |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 51          |
# |    time_elapsed         | 771         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008368705 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.853      |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 54.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | 30.9        |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 52          |
# |    time_elapsed         | 787         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005483408 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 3.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | 32          |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 53          |
# |    time_elapsed         | 803         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.006013069 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 68.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 611         |
# |    ep_rew_mean          | 35.9        |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 54          |
# |    time_elapsed         | 819         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.013278965 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# ...
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 228         |
# |    time_elapsed         | 3713        |
# |    total_timesteps      | 1972224     |
# | train/                  |             |
# |    approx_kl            | 0.006081839 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 9620        |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 229         |
# |    time_elapsed         | 3728        |
# |    total_timesteps      | 1974272     |
# | train/                  |             |
# |    approx_kl            | 0.008248539 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.4        |
# |    n_updates            | 9630        |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 230          |
# |    time_elapsed         | 3743         |
# |    total_timesteps      | 1976320      |
# | train/                  |              |
# |    approx_kl            | 0.0042494573 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.344       |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24           |
# |    n_updates            | 9640         |
# |    policy_gradient_loss | -6.82e-05    |
# |    value_loss           | 164          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 368         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 231         |
# |    time_elapsed         | 3759        |
# |    total_timesteps      | 1978368     |
# | train/                  |             |
# |    approx_kl            | 0.014160552 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.423      |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 9650        |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 94.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 365          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 232          |
# |    time_elapsed         | 3774         |
# |    total_timesteps      | 1980416      |
# | train/                  |              |
# |    approx_kl            | 0.0071352953 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.1         |
# |    n_updates            | 9660         |
# |    policy_gradient_loss | 1.69e-05     |
# |    value_loss           | 150          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 233         |
# |    time_elapsed         | 3788        |
# |    total_timesteps      | 1982464     |
# | train/                  |             |
# |    approx_kl            | 0.010562497 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.83        |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | -0.000735   |
# |    value_loss           | 86.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 367          |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 234          |
# |    time_elapsed         | 3803         |
# |    total_timesteps      | 1984512      |
# | train/                  |              |
# |    approx_kl            | 0.0043944465 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25           |
# |    n_updates            | 9680         |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 161          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 365         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 235         |
# |    time_elapsed         | 3818        |
# |    total_timesteps      | 1986560     |
# | train/                  |             |
# |    approx_kl            | 0.010033593 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.373      |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 98.8        |
# |    n_updates            | 9690        |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 236         |
# |    time_elapsed         | 3833        |
# |    total_timesteps      | 1988608     |
# | train/                  |             |
# |    approx_kl            | 0.011997072 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.5        |
# |    n_updates            | 9700        |
# |    policy_gradient_loss | -0.00107    |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 380         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 237         |
# |    time_elapsed         | 3847        |
# |    total_timesteps      | 1990656     |
# | train/                  |             |
# |    approx_kl            | 0.008584011 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.281      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 9710        |
# |    policy_gradient_loss | -0.000336   |
# |    value_loss           | 86          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 381         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 238         |
# |    time_elapsed         | 3861        |
# |    total_timesteps      | 1992704     |
# | train/                  |             |
# |    approx_kl            | 0.011811547 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 9720        |
# |    policy_gradient_loss | 0.00024     |
# |    value_loss           | 27.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 239          |
# |    time_elapsed         | 3874         |
# |    total_timesteps      | 1994752      |
# | train/                  |              |
# |    approx_kl            | 0.0024124205 |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.404       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 9730         |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 90.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 240         |
# |    time_elapsed         | 3886        |
# |    total_timesteps      | 1996800     |
# | train/                  |             |
# |    approx_kl            | 0.016171794 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.47        |
# |    n_updates            | 9740        |
# |    policy_gradient_loss | 0.000244    |
# |    value_loss           | 28.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 388          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 241          |
# |    time_elapsed         | 3899         |
# |    total_timesteps      | 1998848      |
# | train/                  |              |
# |    approx_kl            | 0.0046085557 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 9750         |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 52.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 386         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 242         |
# |    time_elapsed         | 3911        |
# |    total_timesteps      | 2000896     |
# | train/                  |             |
# |    approx_kl            | 0.003938375 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.8        |
# |    n_updates            | 9760        |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 201         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 243         |
# |    time_elapsed         | 3923        |
# |    total_timesteps      | 2002944     |
# | train/                  |             |
# |    approx_kl            | 0.003927478 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.2        |
# |    n_updates            | 9770        |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 244         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 244          |
# |    time_elapsed         | 3935         |
# |    total_timesteps      | 2004992      |
# | train/                  |              |
# |    approx_kl            | 0.0046601165 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.8         |
# |    n_updates            | 9780         |
# |    policy_gradient_loss | -0.000821    |
# |    value_loss           | 112          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 384          |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 245          |
# |    time_elapsed         | 3947         |
# |    total_timesteps      | 2007040      |
# | train/                  |              |
# |    approx_kl            | 0.0066281753 |
# |    clip_fraction        | 0.0671       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.297       |
# |    explained_variance   | 0.551        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.4         |
# |    n_updates            | 9790         |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 160          |
# ------------------------------------------
# 🏆 Avaliando o modelo no estágio 4: full_difficulty
# 🏆 Avaliação média: 82.19 +/- 139.83

# %%
model.save("./saved_models/ppo_curriculum_lunar_long")
