# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

tmp_path = "./results/ppo-baseline-lunarlander"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

env = gym.make("LunarLander-v3")
model = PPO(policy="MlpPolicy", env=env)

model.set_logger(new_logger)
model.learn(total_timesteps=400_000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Logging to ./results/ppo-baseline-lunarlander
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.9     |
# |    ep_rew_mean     | -158     |
# | time/              |          |
# |    fps             | 565      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.4        |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013171007 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00293     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 343         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00649    |
# |    value_loss           | 1.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.8        |
# |    ep_rew_mean          | -172        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004905694 |
# |    clip_fraction        | 0.00244     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00974    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 615         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 1.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -162        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 4           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009954975 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00298    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 336         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00982    |
# |    value_loss           | 963         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 5           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007098797 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0423      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 319         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00774    |
# |    value_loss           | 565         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -158         |
# | time/                   |              |
# |    fps                  | 365          |
# |    iterations           | 6            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0067382865 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0975      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 459          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00731     |
# |    value_loss           | 944          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 7           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016206669 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00254    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 191         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 467         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 8           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011802284 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.000362   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 308         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 9           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011578884 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.00106     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 199         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 612         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | -133         |
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 10           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0044272724 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.0973       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00445     |
# |    value_loss           | 205          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | -129        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 11          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007911521 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.00458    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 274         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00883    |
# |    value_loss           | 676         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 12          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009734916 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.0202     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 186         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 575         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | -126        |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 13          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012120112 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000421    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 177         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 417         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 14          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005416371 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.000624   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 288         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 570         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 15           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0070241075 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.00451      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 169          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00806     |
# |    value_loss           | 407          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 185        |
# |    ep_rew_mean          | -130       |
# | time/                   |            |
# |    fps                  | 353        |
# |    iterations           | 16         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00572026 |
# |    clip_fraction        | 0.00273    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | -0.326     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 136        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00271   |
# |    value_loss           | 315        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 201        |
# |    ep_rew_mean          | -132       |
# | time/                   |            |
# |    fps                  | 357        |
# |    iterations           | 17         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00925287 |
# |    clip_fraction        | 0.0514     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.0367     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 156        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00408   |
# |    value_loss           | 268        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 215          |
# |    ep_rew_mean          | -130         |
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 18           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0074128956 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0386       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.006       |
# |    value_loss           | 213          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 19          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004166527 |
# |    clip_fraction        | 0.00972     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.8        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 238         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -134        |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 20          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006383993 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.8        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 98.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 21          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009531893 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0199      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 394         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 613         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 258          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 22           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0047025457 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0547       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 499          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 23          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005395881 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00528    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 287         |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 24          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008263357 |
# |    clip_fraction        | 0.0175      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -0.122      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 328         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 25          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006917754 |
# |    clip_fraction        | 0.0279      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 191         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 288         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 26          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007151824 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 116         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 27           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0063164085 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.1         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 67.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 340          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 368          |
# |    iterations           | 28           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0055164117 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.324        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.6         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00706     |
# |    value_loss           | 177          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 348         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 29          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007516877 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00719    |
# |    value_loss           | 242         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 358          |
# |    ep_rew_mean          | -98.6        |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 30           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0068923202 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.349        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.5         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00801     |
# |    value_loss           | 120          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | -95         |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 31          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007886019 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 199         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 253         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | -88.2       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 32          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007467976 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.7        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00741    |
# |    value_loss           | 134         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | -86.3       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 33          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005772557 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 150         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 393         |
# |    ep_rew_mean          | -86.9       |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 34          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008360511 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | -87.8       |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 35          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006946626 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00818    |
# |    value_loss           | 88.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | -83          |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 36           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0073850164 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.9         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00821     |
# |    value_loss           | 56.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 413         |
# |    ep_rew_mean          | -82.1       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 37          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008767153 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00815    |
# |    value_loss           | 62.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | -73.2       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 38          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011086068 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.7        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00879    |
# |    value_loss           | 73.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 437        |
# |    ep_rew_mean          | -69.8      |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 39         |
# |    time_elapsed         | 213        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01189586 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.821     |
# |    explained_variance   | 0.446      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 68.6       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00922   |
# |    value_loss           | 182        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 447         |
# |    ep_rew_mean          | -66.5       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 40          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005207163 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 31.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | -64.6        |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 41           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0038669081 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.7         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00578     |
# |    value_loss           | 63.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 464        |
# |    ep_rew_mean          | -59.2      |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 42         |
# |    time_elapsed         | 229        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.02044154 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.854     |
# |    explained_variance   | 0.63       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.08       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 83.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -52.5       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 43          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006965239 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.3        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 66.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 485         |
# |    ep_rew_mean          | -43.9       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 44          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006583183 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85          |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00621    |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -37.8       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 45          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.024600176 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.3        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0095     |
# |    value_loss           | 81.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 503          |
# |    ep_rew_mean          | -31          |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 46           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0072815614 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.8         |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.52         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00577     |
# |    value_loss           | 30.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 508         |
# |    ep_rew_mean          | -25.7       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 47          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.043361373 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.16        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 97.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 518         |
# |    ep_rew_mean          | -19.1       |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 48          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005696363 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 118         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 519        |
# |    ep_rew_mean          | -7.14      |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 49         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00395554 |
# |    clip_fraction        | 0.045      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.862     |
# |    explained_variance   | 0.468      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.7       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00527   |
# |    value_loss           | 192        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 532         |
# |    ep_rew_mean          | 6.02        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 50          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006706486 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.4        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00592    |
# |    value_loss           | 198         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 537          |
# |    ep_rew_mean          | 9.8          |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 51           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0045666792 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.492        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.3         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 532         |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 52          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005217692 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.1        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 90.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 533         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 53          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.007474892 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.886      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.9        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 169         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 542         |
# |    ep_rew_mean          | 26.9        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 54          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.006043306 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28          |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 59.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 555          |
# |    ep_rew_mean          | 31.1         |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 55           |
# |    time_elapsed         | 299          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0019887239 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.881       |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 0.0003       |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 445          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 223          |
# |    iterations           | 179          |
# |    time_elapsed         | 1637         |
# |    total_timesteps      | 366592       |
# | train/                  |              |
# |    approx_kl            | 0.0047174566 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.76         |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 56.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 436        |
# |    ep_rew_mean          | 175        |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 180        |
# |    time_elapsed         | 1656       |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.01106902 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.687     |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2          |
# |    n_updates            | 1790       |
# |    policy_gradient_loss | -0.00432   |
# |    value_loss           | 9.62       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 181         |
# |    time_elapsed         | 1677        |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.005602956 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 40.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 440         |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 182         |
# |    time_elapsed         | 1700        |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.008526172 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.618      |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.94        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 35.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 447          |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 183          |
# |    time_elapsed         | 1714         |
# |    total_timesteps      | 374784       |
# | train/                  |              |
# |    approx_kl            | 0.0036309771 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.648       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61           |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 447         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 184         |
# |    time_elapsed         | 1731        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.011274826 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00543    |
# |    value_loss           | 3.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 442          |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 215          |
# |    iterations           | 185          |
# |    time_elapsed         | 1754         |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0034504659 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.523       |
# |    explained_variance   | 0.693        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63           |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 94.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 440         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 186         |
# |    time_elapsed         | 1778        |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.009479317 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 107         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | 187          |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 187          |
# |    time_elapsed         | 1798         |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0047213705 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.8         |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 72           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 427          |
# |    ep_rew_mean          | 192          |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 188          |
# |    time_elapsed         | 1822         |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0057668476 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.621       |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.3         |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 46           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 189         |
# |    time_elapsed         | 1853        |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.004626558 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.00386    |
# |    value_loss           | 55.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 428         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 190         |
# |    time_elapsed         | 1882        |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.001678875 |
# |    clip_fraction        | 0.0246      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 38.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 419        |
# |    ep_rew_mean          | 192        |
# | time/                   |            |
# |    fps                  | 204        |
# |    iterations           | 191        |
# |    time_elapsed         | 1916       |
# |    total_timesteps      | 391168     |
# | train/                  |            |
# |    approx_kl            | 0.00550865 |
# |    clip_fraction        | 0.0765     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.624     |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.3       |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | -0.00284   |
# |    value_loss           | 24         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 429         |
# |    ep_rew_mean          | 192         |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 192         |
# |    time_elapsed         | 1938        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.005025441 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.48        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.00327    |
# |    value_loss           | 67.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 420          |
# |    ep_rew_mean          | 196          |
# | time/                   |              |
# |    fps                  | 201          |
# |    iterations           | 193          |
# |    time_elapsed         | 1959         |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0064848554 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.623       |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.14         |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 36.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 417         |
# |    ep_rew_mean          | 194         |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 194         |
# |    time_elapsed         | 1981        |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.003831739 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 92          |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00099    |
# |    value_loss           | 90.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 195          |
# |    time_elapsed         | 1996         |
# |    total_timesteps      | 399360       |
# | train/                  |              |
# |    approx_kl            | 0.0059355046 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.627       |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.44         |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.000594    |
# |    value_loss           | 80.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 196          |
# |    time_elapsed         | 2007         |
# |    total_timesteps      | 401408       |
# | train/                  |              |
# |    approx_kl            | 0.0062021604 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.16         |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 33.6         |
# ------------------------------------------
# Mean reward: 178.5834282 +/- 111.53

# %%
from stable_baselines3 import PPO, DQN, A2C
import gymnasium as gym
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy

tmp_path = "./results/ppo-baseline-lunarlander-long-1"
new_logger = configure(tmp_path, ["stdout", "csv", "tensorboard"])

env = gym.make("LunarLander-v3",
               continuous=False,
               gravity=-10.0,
               enable_wind=True,
               wind_power=15.0,
               turbulence_power=1.5)

model = PPO(policy="MlpPolicy", env=env)

model.set_logger(new_logger)
model.learn(total_timesteps=2_000_000)

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Logging to ./results/ppo-baseline-lunarlander-long-1
# c:\Users\gabri\anaconda3\envs\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.8     |
# |    ep_rew_mean     | -283     |
# | time/              |          |
# |    fps             | 485      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.4         |
# |    ep_rew_mean          | -262         |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0063920487 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00228      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+03      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00832     |
# |    value_loss           | 3.59e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | -253         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 3            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0073391413 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00135     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.24e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 2.41e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.4        |
# |    ep_rew_mean          | -249        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009777602 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00828    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 843         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 2.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | -229         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 5            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0061136186 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00492     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 744          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00708     |
# |    value_loss           | 1.81e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.4        |
# |    ep_rew_mean          | -218        |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 6           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005216958 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0134     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 364         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 911         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.7        |
# |    ep_rew_mean          | -195        |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 7           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009362202 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00147    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 505         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 878         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.9         |
# |    ep_rew_mean          | -173         |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 8            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0080471765 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00123     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 403          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 793          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.4        |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 9           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010185594 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 2.87e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 342         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00987    |
# |    value_loss           | 434         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.7         |
# |    ep_rew_mean          | -159         |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 10           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0062813787 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00962     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 464          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 904          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.2        |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 11          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008933696 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.000935   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 512         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 691         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.2        |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 12          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008729425 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 2.63e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 261         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 503         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.5        |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 13          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009751255 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 7.71e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 293         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 534         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.2        |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 14          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009238363 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -4.43e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 332         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 517         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 15          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009175523 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.0143     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00717    |
# |    value_loss           | 422         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 16          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010251351 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 5.24e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 350         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 17          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007839238 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.000111    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00578    |
# |    value_loss           | 414         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 18           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0023678718 |
# |    clip_fraction        | 0.00835      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.00438      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 248          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 520          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 19           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0074515343 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | -0.00198     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 203          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 430          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | -98          |
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 20           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0035528606 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0121       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 157          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 538          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 125          |
# |    ep_rew_mean          | -96          |
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 21           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0034694583 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00134     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 248          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 388          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | -89.2        |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 22           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0057358053 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.086       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 245          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 543          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -84.2       |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 23          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008265271 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.000193   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 189         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00738    |
# |    value_loss           | 338         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | -81.1       |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 24          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009097189 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -5.81e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 272         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00609    |
# |    value_loss           | 432         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | -77         |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 25          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005671194 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.000125   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 154         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 400         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | -74.9       |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 26          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014490325 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 5.37e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 245         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00522    |
# |    value_loss           | 520         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | -69.3       |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 27          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006775803 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00108    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.1        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 262         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -67.8       |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 28          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015406829 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | -2.19e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 128         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 500         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 166         |
# |    ep_rew_mean          | -64.4       |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 29          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009230356 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.92       |
# |    explained_variance   | -8.33e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 292         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 491         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -58.9       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 30          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008510038 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 8.75e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.1        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 279         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | -57         |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 31          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007415625 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.000434    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 153         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 251         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -57.3       |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 32          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004985418 |
# |    clip_fraction        | 0.00723     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.00286     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 239         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 455         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 204          |
# |    ep_rew_mean          | -52.9        |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 33           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0022329711 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.226        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 348          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 222          |
# |    ep_rew_mean          | -49.6        |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 34           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0065365126 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.911       |
# |    explained_variance   | 0.00596      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 150          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00456     |
# |    value_loss           | 356          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 235        |
# |    ep_rew_mean          | -48.1      |
# | time/                   |            |
# |    fps                  | 372        |
# |    iterations           | 35         |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.00427113 |
# |    clip_fraction        | 0.017      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.975     |
# |    explained_variance   | 0.0102     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 72.6       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0034    |
# |    value_loss           | 200        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | -46.5       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 36          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007273406 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | 0.0971      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 358         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 264          |
# |    ep_rew_mean          | -49.5        |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 37           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0080515165 |
# |    clip_fraction        | 0.0723       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.0975       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 137          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00894     |
# |    value_loss           | 372          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 279          |
# |    ep_rew_mean          | -46.7        |
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 38           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0040632803 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.913       |
# |    explained_variance   | -0.0323      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 132          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 342          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | -45.5       |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 39          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008471194 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.874      |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 184         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | -43.6       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 40          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013343641 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0.0309      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.3        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 230         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | -43.5       |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 41          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008244305 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.8        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00665    |
# |    value_loss           | 212         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 319          |
# |    ep_rew_mean          | -42.5        |
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 42           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0077278684 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.807       |
# |    explained_variance   | 0.0965       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 205          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00585     |
# |    value_loss           | 333          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 329         |
# |    ep_rew_mean          | -48.6       |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 43          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006121944 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | -0.246      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.2        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00358    |
# |    value_loss           | 201         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | -44.9        |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 44           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0029976997 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.883       |
# |    explained_variance   | 0.0386       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 247          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 473          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | -44.4       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 45          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007148339 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 0.0698      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 299         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 355         |
# |    ep_rew_mean          | -42.5       |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 46          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012931878 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 158         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | -41.8       |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 47          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007872738 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 218         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 382         |
# |    ep_rew_mean          | -39         |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 48          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010626268 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.1        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00779    |
# |    value_loss           | 148         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 382       |
# |    ep_rew_mean          | -45.6     |
# | time/                   |           |
# |    fps                  | 375       |
# |    iterations           | 49        |
# |    time_elapsed         | 267       |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0111481 |
# |    clip_fraction        | 0.0967    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.937    |
# |    explained_variance   | 0.266     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 42.3      |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.00574  |
# |    value_loss           | 77.7      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 392          |
# |    ep_rew_mean          | -45.9        |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 50           |
# |    time_elapsed         | 273          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0043988675 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.851       |
# |    explained_variance   | 0.175        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 183          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 317          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 407        |
# |    ep_rew_mean          | -42.1      |
# | time/                   |            |
# |    fps                  | 375        |
# |    iterations           | 51         |
# |    time_elapsed         | 278        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.00489115 |
# |    clip_fraction        | 0.0245     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.826     |
# |    explained_variance   | 0.367      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 93.7       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.00535   |
# |    value_loss           | 254        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 406          |
# |    ep_rew_mean          | -36.7        |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 52           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0133850295 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00826     |
# |    value_loss           | 159          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 416         |
# |    ep_rew_mean          | -35.4       |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 53          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008197558 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | -37.1       |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 54          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.003411831 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 121         |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 491         |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 960         |
# |    time_elapsed         | 4992        |
# |    total_timesteps      | 1966080     |
# | train/                  |             |
# |    approx_kl            | 0.011844595 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.425      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 9590        |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 58.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 961         |
# |    time_elapsed         | 4997        |
# |    total_timesteps      | 1968128     |
# | train/                  |             |
# |    approx_kl            | 0.002983554 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.25       |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 9600        |
# |    policy_gradient_loss | -0.000108   |
# |    value_loss           | 89.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 473         |
# |    ep_rew_mean          | 180         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 962         |
# |    time_elapsed         | 5001        |
# |    total_timesteps      | 1970176     |
# | train/                  |             |
# |    approx_kl            | 0.006226299 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.301      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 9610        |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 131         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 469         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 963         |
# |    time_elapsed         | 5006        |
# |    total_timesteps      | 1972224     |
# | train/                  |             |
# |    approx_kl            | 0.008731842 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.6         |
# |    n_updates            | 9620        |
# |    policy_gradient_loss | -0.00244    |
# |    value_loss           | 25.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 475          |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 964          |
# |    time_elapsed         | 5011         |
# |    total_timesteps      | 1974272      |
# | train/                  |              |
# |    approx_kl            | 0.0125963595 |
# |    clip_fraction        | 0.0804       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.339       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.7         |
# |    n_updates            | 9630         |
# |    policy_gradient_loss | -0.00488     |
# |    value_loss           | 56.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 965         |
# |    time_elapsed         | 5015        |
# |    total_timesteps      | 1976320     |
# | train/                  |             |
# |    approx_kl            | 0.005241272 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.373      |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 9640        |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 61.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 484        |
# |    ep_rew_mean          | 181        |
# | time/                   |            |
# |    fps                  | 394        |
# |    iterations           | 966        |
# |    time_elapsed         | 5020       |
# |    total_timesteps      | 1978368    |
# | train/                  |            |
# |    approx_kl            | 0.07322371 |
# |    clip_fraction        | 0.0997     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.454     |
# |    explained_variance   | 0.851      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.2       |
# |    n_updates            | 9650       |
# |    policy_gradient_loss | -0.00195   |
# |    value_loss           | 24.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 486          |
# |    ep_rew_mean          | 181          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 967          |
# |    time_elapsed         | 5025         |
# |    total_timesteps      | 1980416      |
# | train/                  |              |
# |    approx_kl            | 0.0036292374 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.314       |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.9         |
# |    n_updates            | 9660         |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 40.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 473         |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 968         |
# |    time_elapsed         | 5029        |
# |    total_timesteps      | 1982464     |
# | train/                  |             |
# |    approx_kl            | 0.005978955 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.339      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.85        |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | 7.81e-06    |
# |    value_loss           | 36          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 451         |
# |    ep_rew_mean          | 188         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 969         |
# |    time_elapsed         | 5034        |
# |    total_timesteps      | 1984512     |
# | train/                  |             |
# |    approx_kl            | 0.014860187 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.23        |
# |    n_updates            | 9680        |
# |    policy_gradient_loss | -0.000413   |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 426         |
# |    ep_rew_mean          | 195         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 970         |
# |    time_elapsed         | 5038        |
# |    total_timesteps      | 1986560     |
# | train/                  |             |
# |    approx_kl            | 0.008316284 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.38       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.51        |
# |    n_updates            | 9690        |
# |    policy_gradient_loss | -0.00048    |
# |    value_loss           | 24.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 397         |
# |    ep_rew_mean          | 197         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 971         |
# |    time_elapsed         | 5043        |
# |    total_timesteps      | 1988608     |
# | train/                  |             |
# |    approx_kl            | 0.004946665 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.55        |
# |    n_updates            | 9700        |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 22.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 972          |
# |    time_elapsed         | 5047         |
# |    total_timesteps      | 1990656      |
# | train/                  |              |
# |    approx_kl            | 0.0050083185 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.285       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 9710         |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 72.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 191         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 973         |
# |    time_elapsed         | 5052        |
# |    total_timesteps      | 1992704     |
# | train/                  |             |
# |    approx_kl            | 0.026145682 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.501      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.95        |
# |    n_updates            | 9720        |
# |    policy_gradient_loss | 0.00172     |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | 192         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 974         |
# |    time_elapsed         | 5056        |
# |    total_timesteps      | 1994752     |
# | train/                  |             |
# |    approx_kl            | 0.006577168 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.401      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.27        |
# |    n_updates            | 9730        |
# |    policy_gradient_loss | 0.000618    |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 406          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 975          |
# |    time_elapsed         | 5061         |
# |    total_timesteps      | 1996800      |
# | train/                  |              |
# |    approx_kl            | 0.0055754003 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.6         |
# |    n_updates            | 9740         |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 56.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 976          |
# |    time_elapsed         | 5065         |
# |    total_timesteps      | 1998848      |
# | train/                  |              |
# |    approx_kl            | 0.0047891177 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 9750         |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 46.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 384          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 977          |
# |    time_elapsed         | 5070         |
# |    total_timesteps      | 2000896      |
# | train/                  |              |
# |    approx_kl            | 0.0071596596 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.298       |
# |    explained_variance   | 0.759        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.97         |
# |    n_updates            | 9760         |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 42.2         |
# ------------------------------------------
# Mean reward: 242.64567460000004 +/- 32.92

# %%
model.save(f"./saved_models/ppo_baseline_lunar_long-1")
